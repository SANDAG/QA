# %% [markdown]
# # ETL Check

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## First Study

# %%
# Data From Replica
first_study_replica_download = pd.read_csv(r'C:\Users\cra\OneDrive - San Diego Association of Governments\QA_Repository\2023\2023-024 Employment Center 2.0\replica-first_study-03_21_23-trips_dataset.csv')
first_study_replica_download
# Out:
#                                 origin_bgrp                origin_cty  \
# 0            1 (Tract 123.02, Imperial, CA)       Imperial County, CA
# 1            1 (Tract 123.01, Imperial, CA)       Imperial County, CA
# 2        3 (Tract 19.03, Santa Barbara, CA)  Santa Barbara County, CA
# 3        3 (Tract 19.03, Santa Barbara, CA)  Santa Barbara County, CA
# 4        2 (Tract 19.03, Santa Barbara, CA)  Santa Barbara County, CA
# ...                                     ...                       ...
# 7557616     2 (Tract 200.19, San Diego, CA)      San Diego County, CA
# 7557617     1 (Tract 200.27, San Diego, CA)      San Diego County, CA
# 7557618     1 (Tract 200.23, San Diego, CA)      San Diego County, CA
# 7557619     1 (Tract 200.29, San Diego, CA)      San Diego County, CA
# 7557620     1 (Tract 198.03, San Diego, CA)      San Diego County, CA
#
#           origin_st                 destination_bgrp       destination_cty  \
# ...

# %%
# Localized Data
first_study_local_download = pd.read_csv(r'J:\DataScience\DSEconProdDessem\EC2\Replica\Trips_to_EC_fall_2019_thursday\replica-first_study-02_14_23-trips_dataset\replica-first_study-02_14_23-trips_dataset.csv')
first_study_local_download
# Out:
#                                 origin_bgrp              origin_cty  \
# 0        1 (Tract 5520.01, Los Angeles, CA)  Los Angeles County, CA
# 1                2 (Tract 1105, Orange, CA)       Orange County, CA
# 2        2 (Tract 5736.01, Los Angeles, CA)  Los Angeles County, CA
# 3        2 (Tract 5039.01, Los Angeles, CA)  Los Angeles County, CA
# 4        4 (Tract 5705.02, Los Angeles, CA)  Los Angeles County, CA
# ...                                     ...                     ...
# 7557616        3 (Tract 221, San Diego, CA)    San Diego County, CA
# 7557617     1 (Tract 198.05, San Diego, CA)    San Diego County, CA
# 7557618     2 (Tract 192.03, San Diego, CA)    San Diego County, CA
# 7557619     1 (Tract 200.21, San Diego, CA)    San Diego County, CA
# 7557620        2 (Tract 221, San Diego, CA)    San Diego County, CA
#
#           origin_st                 destination_bgrp       destination_cty  \
# ...

# %%
first_study_replica_download.columns == first_study_local_download.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
first_study_replica_download.head()
# Out:
#                           origin_bgrp                origin_cty   origin_st  \
# 0      1 (Tract 123.02, Imperial, CA)       Imperial County, CA  California
# 1      1 (Tract 123.01, Imperial, CA)       Imperial County, CA  California
# 2  3 (Tract 19.03, Santa Barbara, CA)  Santa Barbara County, CA  California
# 3  3 (Tract 19.03, Santa Barbara, CA)  Santa Barbara County, CA  California
# 4  2 (Tract 19.03, Santa Barbara, CA)  Santa Barbara County, CA  California
#
#                   destination_bgrp       destination_cty  \
# 0      1 (Tract 62, San Diego, CA)  San Diego County, CA
# 1  1 (Tract 208.06, San Diego, CA)  San Diego County, CA
# 2   1 (Tract 83.62, San Diego, CA)  San Diego County, CA
# 3      1 (Tract 62, San Diego, CA)  San Diego County, CA
# 4      1 (Tract 62, San Diego, CA)  San Diego County, CA
#
#      destination_custom       primary_mode         trip_purpose  \
# 0     San Diego Airport            carpool  other_activity_type
# ...

# %%
first_study_local_download.head()['origin_bgrp'][4]
# Out:
# '4 (Tract 5705.02, Los Angeles, CA)'

# %%
first_study_replica_download[first_study_replica_download['origin_bgrp'] == first_study_local_download.head()['origin_bgrp'][4]]
# Out:
#                                 origin_bgrp              origin_cty  \
# 77322    4 (Tract 5705.02, Los Angeles, CA)  Los Angeles County, CA
# 2889536  4 (Tract 5705.02, Los Angeles, CA)  Los Angeles County, CA
# 3197911  4 (Tract 5705.02, Los Angeles, CA)  Los Angeles County, CA
# 4257205  4 (Tract 5705.02, Los Angeles, CA)  Los Angeles County, CA
# 5753973  4 (Tract 5705.02, Los Angeles, CA)  Los Angeles County, CA
#
#           origin_st              destination_bgrp       destination_cty  \
# 77322    California  1 (Tract 187, San Diego, CA)  San Diego County, CA
# 2889536  California  1 (Tract 187, San Diego, CA)  San Diego County, CA
# 3197911  California  1 (Tract 187, San Diego, CA)  San Diego County, CA
# 4257205  California  1 (Tract 187, San Diego, CA)  San Diego County, CA
# 5753973  California  1 (Tract 187, San Diego, CA)  San Diego County, CA
#
#                        destination_custom  primary_mode trip_purpose  \
# ...

# %%
first_study_replica_download.shape == first_study_local_download.shape
# Out:
# True

# %% [markdown]
# ## Trip Counts by block group

# %%
trip_counts_replica_download = pd.read_csv(r'C:\Users\cra\OneDrive - San Diego Association of Governments\QA_Repository\2023\2023-024 Employment Center 2.0\replica-num_trips_blockgrps_to_ecs_fall_19_thusrday-03_21_23-trips_dataset.csv')
trip_counts_replica_download
# Out:
#                              origin_bgrp            origin_cty   origin_st  \
# 0          1 (Tract 9843, San Mateo, CA)  San Mateo County, CA  California
# 1          1 (Tract 9843, San Mateo, CA)  San Mateo County, CA  California
# 2          1 (Tract 9843, San Mateo, CA)  San Mateo County, CA  California
# 3          2 (Tract 6060, San Mateo, CA)  San Mateo County, CA  California
# 4          1 (Tract 9843, San Mateo, CA)  San Mateo County, CA  California
# ...                                  ...                   ...         ...
# 7557616  2 (Tract 200.19, San Diego, CA)  San Diego County, CA  California
# 7557617  1 (Tract 200.27, San Diego, CA)  San Diego County, CA  California
# 7557618  1 (Tract 200.23, San Diego, CA)  San Diego County, CA  California
# 7557619  1 (Tract 200.29, San Diego, CA)  San Diego County, CA  California
# 7557620  1 (Tract 198.03, San Diego, CA)  San Diego County, CA  California
#
# ...

# %%
trip_counts_local_download = pd.read_csv(r'J:\DataScience\DSEconProdDessem\EC2\Replica\Trips_to_EC_fall_2019_thursday\replica-num_trips_blockgrps_to_ecs_fall_19_thusrday-02_23_23-trips_dataset\replica-num_trips_blockgrps_to_ecs_fall_19_thusrday-02_23_23-trips_dataset.csv')
trip_counts_local_download
# Out:
#                              origin_bgrp            origin_cty  \
# 0                      Outside of region     Outside of region
# 1                      Outside of region     Outside of region
# 2                      Outside of region     Outside of region
# 3                      Outside of region     Outside of region
# 4                      Outside of region     Outside of region
# ...                                  ...                   ...
# 7557616  2 (Tract 197.01, San Diego, CA)  San Diego County, CA
# 7557617  1 (Tract 200.29, San Diego, CA)  San Diego County, CA
# 7557618  2 (Tract 197.01, San Diego, CA)  San Diego County, CA
# 7557619  1 (Tract 200.29, San Diego, CA)  San Diego County, CA
# 7557620  1 (Tract 199.02, San Diego, CA)  San Diego County, CA
#
#                  origin_st        destination_custom       primary_mode  \
# 0        Outside of region               Ocean Beach  other_travel_mode
# ...

# %%
trip_counts_replica_download.columns == trip_counts_local_download.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
trip_counts_replica_download.shape == trip_counts_local_download.shape
# Out:
# True

# %% [markdown]
# # Downloading local data

# %%
df.columns[2]
# Out:
# ('Unnamed: 2_level_0', 'EC Tier')
