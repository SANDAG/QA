# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Doewnload The Data

# %%
raw_pums_data = pd.read_csv('PUMSsubset_SanDiego-2017-2021.txt', delimiter='\t')
raw_pums_data
# Out:
#              SERIALNO  SPORDER  PUMA  ST   ADJINC  PWGTP  AGEP  COW  MIL  \
# 0       2017000000336        1  7307   6  1117630     14    33  1.0  4.0
# 1       2017000000336        2  7307   6  1117630     12    30  2.0  4.0
# 2       2017000000634        1  7301   6  1117630     25    63  2.0  4.0
# 3       2017000000634        2  7301   6  1117630     24    69  1.0  4.0
# 4       2017000000634        3  7301   6  1117630     39    27  1.0  4.0
# ...               ...      ...   ...  ..      ...    ...   ...  ...  ...
# 143742  2021HU1415442        1  7312   6  1029928     16    62  1.0  4.0
# 143743  2021HU1415478        1  7321   6  1029928      8    76  6.0  4.0
# 143744  2021HU1415547        1  7315   6  1029928     27    54  1.0  4.0
# 143745  2021HU1415547        2  7315   6  1029928     21    59  6.0  4.0
# 143746  2021HU1415547        3  7315   6  1029928     32    18  1.0  4.0
#
#         RELSHIPP  ...  WGTP  TYPEHUGQ  HHT     HINCP  Year  Age  NonHispanic  \
# ...
