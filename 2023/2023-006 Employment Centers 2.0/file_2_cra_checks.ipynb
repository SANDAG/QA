# %%
# Libraries 
import numpy as np
import pandas as pd
import pyodbc
import copy

# %% [markdown]
# # EC2_Data_file_2_Build

# %% [markdown]
# ## Downloading the SQL Data

# %%
# Staging Data (SQL)
conn = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
                    'Server=DDAMWSQL16.sandag.org;'
                    'Database=ws;'
                    'Trusted_Connection=yes;')

# %%
query = """
-- For JT00
DECLARE	@return_value int

EXEC	@return_value = [employment_centers].[sp_wac_characteristics_by_center_JT00]
		@release_id = 2
"""

sql_jt00 =  pd.read_sql_query(query, conn)

# %%
query = """
-- For JT02
DECLARE	@return_value int

EXEC	@return_value = [employment_centers].[sp_wac_characteristics_by_center_JT02]
		@release_id = 2
"""

sql_jt02 =  pd.read_sql_query(query, conn)

# %%
query = """
-- Jobs by Average Wage
DECLARE	@return_value int

EXEC	@return_value = [employment_centers].[sp_avg_wage_by_center]
		@release_id = 2
"""

sql_j_avg_wage =  pd.read_sql_query(query, conn)

# %%
sql_j_avg_wage[['employment_center', 'avg_wage']]
# Out:
#      employment_center  avg_wage
# 0                    1     49360
# 1                    2     50038
# 2                    3     52719
# 3                    4     86672
# 4                    5     58862
# ..                 ...       ...
# 142               1039    107258
# 143               1040    111149
# 144               1041     86679
# 145               1042    124000
# 146               1043     31870
#
# [147 rows x 2 columns]

# %%
def avg_wage_grab(conn):
    query = """
        DECLARE	@return_value int

        EXEC	@return_value = [employment_centers].[sp_avg_wage_by_center]
                @release_id = 2
        """

    return pd.read_sql_query(query, conn)[['employment_center', 'avg_wage']].set_index('employment_center')

# %%
avg_wage_grab()
# Out:
#                    avg_wage
# employment_center
# 1                     49360
# 2                     50038
# 3                     52719
# 4                     86672
# 5                     58862
# ...                     ...
# 1039                 107258
# 1040                 111149
# 1041                  86679
# 1042                 124000
# 1043                  31870
#
# [147 rows x 1 columns]

# %%
query = """
-- EC List Info 
SELECT [employment_center_id],
	[employment_center_name],
	[tier],
	[parent]
  FROM [ws].[employment_centers].[dim_employment_center_2.0]
"""

ec_list =  pd.read_sql_query(query, conn)

# %%
ec_list['Type'] = np.where((ec_list['tier'] == 0) & (ec_list['parent'].isna()), 'Combined Center',
                            np.where((ec_list['tier'] == 0) & (~ec_list['parent'].isna()), 'Sub-Center',
                                     np.nan))

# %%
ec_list.set_index('employment_center_id')
# Out:
#                                                  employment_center_name  tier  \
# employment_center_id
# 55                                                Otay Mesa Brown Field     4
# 56                                                       Otay Mesa East     4
# 57                                                        Pacific Beach     3
# 58                                                                Poway     4
# 59                                                               Ramona     4
# ...                                                                 ...   ...
# 1004                       Carslabd Palomar Airport Sub-Center: Melrose     0
# 1005                  Carslabd Palomar Airport Sub-Center: Palomar Oaks     0
# 1006                                  Downtown Sub-Center: Bankers Hill     0
# 1007                                      Downtown Sub-Center: Columbia     0
# 1008                                   Downtown Sub-Center: Cortez Hill     0
#
#                       parent        Type
# employment_center_id
# 55                       NaN         nan
# 56                       NaN         nan
# 57                       NaN         nan
# 58                       NaN         nan
# 59                       NaN         nan
# ...                      ...         ...
# 1004                     4.0  Sub-Center
# 1005                     4.0  Sub-Center
# 1006                    18.0  Sub-Center
# 1007                    18.0  Sub-Center
# 1008                    18.0  Sub-Center
#
# [147 rows x 4 columns]

# %% [markdown]
# # JT00 Work

# %%
# Staging Data (SQL)
conn = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
                    'Server=DDAMWSQL16.sandag.org;'
                    'Database=ws;'
                    'Trusted_Connection=yes;')

# %%
def download_and_clean_employment_center_data(conn):
    query = """
            -- EC List Info 
            SELECT [employment_center_id],
                [employment_center_name],
                [tier],
                [parent]
            FROM [ws].[employment_centers].[dim_employment_center_2.0]
            """
    ec_list =  pd.read_sql_query(query, conn)

    ec_list['Type'] = np.where((ec_list['tier'] == 0) & (ec_list['parent'].isna()), 'Combined Center',
                            np.where((ec_list['tier'] == 0) & (~ec_list['parent'].isna()), 'Sub-Center',
                                     np.nan))
    ec_list['Type'].replace('nan', np.nan, inplace=True)
    return ec_list.set_index('employment_center_id').sort_index(ascending=True)

# %%
def avg_wage_grab(conn):
    query = """
        DECLARE	@return_value int

        EXEC	@return_value = [employment_centers].[sp_avg_wage_by_center]
                @release_id = 2
        """

    return pd.read_sql_query(query, conn)[['employment_center', 'avg_wage']].set_index('employment_center')

# %%
def download_jt_data(JT_Val, conn):
    """
    Downloads the proper JTtable
    Input opitons are: 'JT00' and 'JT02' 
    """
    query = f"""
    DECLARE	@return_value int

    EXEC	@return_value = [employment_centers].[sp_wac_characteristics_by_center_{JT_Val}]
            @release_id = 2
    """

    return  pd.read_sql_query(query, conn)

# %%
def build_df_and_find_percentages(SQL_Data, is_all):
    # Cleaning 
    sql_prep = copy.deepcopy(SQL_Data)
    sql_prep = sql_prep.drop(['tier', 'employment_center_name'], axis = 1)
    sql_prep = sql_prep.set_index('employment_center_id')

    # Drop columns that sum to zero, should only effect JT00
    to_drop = sql_prep.columns[(sql_prep == 0).all()].tolist()
    sql_prep = sql_prep.drop(columns=to_drop)

    # Grab and delete total 
    total = sql_prep['jobs']
    sql_prep = sql_prep.drop('jobs', axis = 1)

    output_df = pd.DataFrame(index=sql_prep.index)

    # Check and set status of employment level that we are looking at 
    if is_all:
        employment_status = 'All_Jobs'
    else:
        employment_status = 'Priv_Jobs'

    # Set the core columns 
    for col in sql_prep.columns: 
        output_df[f"{employment_status}_{col}"] = sql_prep[col]

    # Calculate the remaining columns 
    for col in sql_prep.columns:
        if 'educ30' in col:
            output_df[f"{employment_status}_%_{col}"] = round(sql_prep[col] / (total-sql_prep['age_lt30']) , 4) * 100
        else: 
            output_df[f"{employment_status}_%_{col}"] = round(sql_prep[col] / total, 4) * 100

    output_df.insert(0, f'{employment_status}_Total', total)

    output_df = output_df.sort_index(ascending=True)

    return output_df

# %%
def main():
    ec_list = download_and_clean_employment_center_data(conn)
    JT00 = download_jt_data(JT_Val='JT00', conn=conn)
    print('JT00 is downloaded')
    JT02 = download_jt_data(JT_Val='JT02', conn=conn)
    print('JT02 is downloaded')
    averge_wage = avg_wage_grab(conn)
    print('Average wage downloaded')

    print('Now Processing JT00 and JT02 Data')
    processed_JT00 = build_df_and_find_percentages(JT00, is_all=True)
    processed_JT02 = build_df_and_find_percentages(JT02, is_all=False)

    output = ec_list.merge(processed_JT00, how='left', left_index=True, right_index=True).merge(processed_JT02, how='left', left_index=True, right_index=True).merge(averge_wage, how='left', left_index=True, right_index=True)

    output.fillna(0, inplace=True)

    return output

# %%
output = main()
output
# Out:
# JT00 is downloaded
# JT02 is downloaded
# Average wage downloaded
# Now Processing JT00 and JT02 Data
#                                                  employment_center_name  tier  \
# employment_center_id
# 1                                                     San Diego Airport     3
# 2                                                                Alpine     4
# 3                                                          Barrio Logan     4
# 4                                              Carlsbad Palomar Airport     2
# 5                                                  Carlsbad State Beach     3
# ...                                                                 ...   ...
# 1039                  Sorrento Valley West Sub-Center: Scripps_Research     0
# 1040                              Sorrento Valley West Sub-Center: UCSD     0
# 1041                  Sorrento Valley West Sub-Center: UCSD East Hea...     0
# 1042                        Sorrento Valley West Sub-Center: UTC Office     0
# 1043                        Sorrento Valley West Sub-Center: UTC Retail     0
#
#                       parent        Type  All_Jobs_Total  All_Jobs_male  \
# employment_center_id
# 1                        0.0         nan         18782.0        10570.0
# 2                        0.0         nan          1230.0          541.0
# 3                        0.0         nan          4230.0         2555.0
# 4                        0.0         nan         31627.0        17763.0
# 5                        0.0         nan         11510.0         6049.0
# ...                      ...         ...             ...            ...
# 1039                    71.0  Sub-Center         14210.0         7067.0
# 1040                    71.0  Sub-Center         22865.0         9702.0
# 1041                    71.0  Sub-Center         18304.0         8340.0
# 1042                    71.0  Sub-Center         14171.0         7774.0
# 1043                    71.0  Sub-Center          3079.0         1300.0
#
#                       All_Jobs_female  All_Jobs_age_lt30  All_Jobs_age_30to54  \
# employment_center_id
# 1                              8212.0             4508.0              10083.0
# 2                               689.0              324.0                630.0
# 3                              1675.0              934.0               2348.0
# 4                             13864.0             6369.0              18450.0
# 5                              5461.0             3822.0               5458.0
# ...                               ...                ...                  ...
# 1039                           7143.0             1801.0               9168.0
# 1040                          13163.0             2923.0              14823.0
# 1041                           9964.0             2738.0              11790.0
# 1042                           6397.0             3149.0               8578.0
# 1043                           1779.0             1352.0               1336.0
#
#                       All_Jobs_age_55plus  ...  \
# employment_center_id                       ...
# 1                                  4191.0  ...
# 2                                   276.0  ...
# 3                                   948.0  ...
# 4                                  6808.0  ...
# 5                                  2230.0  ...
# ...                                   ...  ...
# 1039                               3241.0  ...
# 1040                               5119.0  ...
# 1041                               3776.0  ...
# 1042                               2444.0  ...
# 1043                                391.0  ...
#
#                       Priv_Jobs_%_jobs_firms_age_2_to_3  \
# employment_center_id
# 1                                                  5.69
# 2                                                  8.01
# 3                                                  5.59
# 4                                                  4.87
# 5                                                  1.58
# ...                                                 ...
# 1039                                               2.25
# 1040                                               2.26
# 1041                                               0.39
# 1042                                               4.83
# 1043                                               2.27
#
#                       Priv_Jobs_%_jobs_firms_age_4_to_5  \
# employment_center_id
# 1                                                  3.59
# 2                                                  5.40
# 3                                                  2.79
# 4                                                  2.63
# 5                                                  3.00
# ...                                                 ...
# 1039                                               3.05
# 1040                                               9.15
# 1041                                               1.24
# 1042                                               6.67
# 1043                                               3.22
#
#                       Priv_Jobs_%_jobs_firms_age_6_to_10  \
# employment_center_id
# 1                                                   9.18
# 2                                                  18.03
# 3                                                   5.36
# 4                                                   9.41
# 5                                                   9.02
# ...                                                  ...
# 1039                                                7.77
# 1040                                                6.55
# 1041                                                9.74
# 1042                                               10.56
# 1043                                                6.82
#
#                       Priv_Jobs_%_jobs_firms_age_11_plus  \
# employment_center_id
# 1                                                  79.01
# 2                                                  66.81
# 3                                                  82.96
# 4                                                  80.40
# 5                                                  85.75
# ...                                                  ...
# 1039                                               83.40
# 1040                                               79.55
# 1041                                               88.03
# 1042                                               75.61
# 1043                                               72.72
#
#                       Priv_Jobs_%_jobs_firms_size_0_to_19  \
# employment_center_id
# 1                                                   15.87
# 2                                                   34.06
# 3                                                   20.41
# 4                                                   15.28
# 5                                                    9.16
# ...                                                   ...
# 1039                                                 4.48
# 1040                                                16.50
# 1041                                                 4.32
# 1042                                                12.35
# 1043                                                 4.06
#
#                       Priv_Jobs_%_jobs_firms_size_20_to_49  \
# employment_center_id
# 1                                                    12.97
# 2                                                    24.48
# 3                                                    17.21
# 4                                                    11.92
# 5                                                     5.98
# ...                                                    ...
# 1039                                                  5.10
# 1040                                                 10.85
# 1041                                                  1.33
# 1042                                                  8.45
# 1043                                                  2.73
#
#                       Priv_Jobs_%_jobs_firms_size_50_to_249  \
# employment_center_id
# 1                                                     21.67
# 2                                                     29.70
# 3                                                     11.02
# 4                                                     20.31
# 5                                                     14.67
# ...                                                     ...
# 1039                                                   8.30
# 1040                                                  44.41
# 1041                                                   9.83
# 1042                                                  17.54
# 1043                                                  17.18
#
#                       Priv_Jobs_%_jobs_firms_size_250_to_499  \
# employment_center_id
# 1                                                       3.89
# 2                                                       0.26
# 3                                                       2.94
# 4                                                       7.74
# 5                                                      10.63
# ...                                                      ...
# 1039                                                    7.29
# 1040                                                    0.90
# 1041                                                    7.62
# 1042                                                    2.22
# 1043                                                    0.13
#
#                       Priv_Jobs_%_jobs_firms_size_500_plus  avg_wage
# employment_center_id
# 1                                                    45.60     49360
# 2                                                    11.50     50038
# 3                                                    48.41     52719
# 4                                                    44.76     86672
# 5                                                    59.57     58862
# ...                                                    ...       ...
# 1039                                                 74.82    107258
# 1040                                                 27.34    111149
# 1041                                                 76.90     86679
# 1042                                                 59.44    124000
# 1043                                                 75.90     31870
#
# [147 rows x 75 columns]

# %%
output['Type'][2]
# Out:
# 'nan'
