# %% [markdown]
# # CRA Employment Checks

# %%
# Libraries 
import numpy as np
import pandas as pd
import pyodbc

# %% [markdown]
# # EC2_Data_File1_Build

# %% [markdown]
# ## 1. Reviewing SQL Data Extract
# Ensuring that the SQL output matches what we have in the excel

# %% [markdown]
# ### Downloading Data From SQL

# %%
# Staging Data (SQL)
conn = pyodbc.connect('Driver={ODBC Driver 17 for SQL Server};'
                    'Server=DDAMWSQL16.sandag.org;'
                    'Database=ws;'
                    'Trusted_Connection=yes;')

# %%
query = """
-- Population by Age
DECLARE	@return_value int

EXEC	@return_value = [employment_centers].[sp_age_by_center]
		@release_id = 2,
		@demographic_warehouse_datasource_id = 45,
		@year = 2021
"""

Pop_by_Age_SQL =  pd.read_sql_query(query, conn)
Pop_by_Age_SQL
# Out:
#       tier  employment_center_id  employment_center_name  age_group_id  \
# 0        0                    80             Kearny Mesa             7
# 1        0                    80             Kearny Mesa            11
# 2        0                    80             Kearny Mesa             2
# 3        0                    80             Kearny Mesa            20
# 4        0                    80             Kearny Mesa            18
# ...    ...                   ...                     ...           ...
# 2915     6                   108  Viejas Casino & Resort             7
# 2916     6                   108  Viejas Casino & Resort             9
# 2917     6                   108  Viejas Casino & Resort            13
# 2918     6                   108  Viejas Casino & Resort            16
# 2919     6                   108  Viejas Casino & Resort            18
#
#          age_group   pop
# 0         25 to 29  1203
# 1         45 to 49  1199
# 2           5 to 9  1339
# 3     85 and Older   360
# 4         75 to 79   511
# ...            ...   ...
# 2915      25 to 29    34
# 2916      35 to 39    29
# 2917      55 to 59    28
# 2918      65 to 69    31
# 2919      75 to 79    23
#
# [2920 rows x 6 columns]

# %%
query = """
-- Population by HH & GQ
DECLARE	@return_value int

EXEC	@return_value = [employment_centers].[sp_demographics_by_center]
		@release_id = 2,
		@demographic_warehouse_datasource_id = 45,
		@year = 2021
"""

Pop_by_Type_SQL =  pd.read_sql_query(query, conn)
Pop_by_Type_SQL
# Out:
#      tier  employment_center_id      employment_center_name  housing_type_id  \
# 0       0                    80                 Kearny Mesa                1
# 1       0                    80                 Kearny Mesa                2
# 2       0                    80                 Kearny Mesa                3
# 3       0                    80                 Kearny Mesa                4
# 4       0                    81             Sorrento Valley                1
# ..    ...                   ...                         ...              ...
# 579     6                   107  Valley View Casino & Hotel                4
# 580     6                   108      Viejas Casino & Resort                1
# 581     6                   108      Viejas Casino & Resort                2
# 582     6                   108      Viejas Casino & Resort                3
# 583     6                   108      Viejas Casino & Resort                4
#
#                      long_name    pop
# 0         Household Population  19610
# 1    Group Quarters - Military      0
# 2     Group Quarters - College      0
# 3       Group Quarters - Other     71
# 4         Household Population  48782
# ..                         ...    ...
# 579     Group Quarters - Other      1
# 580       Household Population    538
# 581  Group Quarters - Military      0
# 582   Group Quarters - College      0
# 583     Group Quarters - Other      0
#
# [584 rows x 6 columns]

# %%
query = """
-- Population by Race/Ethnicity
DECLARE	@return_value int

EXEC	@return_value = [employment_centers].[sp_ethnicity_by_center]
		@release_id = 2,
		@demographic_warehouse_datasource_id = 45,
		@year = 2021
"""

Pop_by_Race_Eth_SQL =  pd.read_sql_query(query, conn)
Pop_by_Race_Eth_SQL
# Out:
#       tier  employment_center_id  employment_center_name  ethnicity_id  \
# 0        0                    80             Kearny Mesa             1
# 1        0                    80             Kearny Mesa             2
# 2        0                    80             Kearny Mesa             3
# 3        0                    80             Kearny Mesa             4
# 4        0                    80             Kearny Mesa             5
# ...    ...                   ...                     ...           ...
# 1163     6                   108  Viejas Casino & Resort             4
# 1164     6                   108  Viejas Casino & Resort             5
# 1165     6                   108  Viejas Casino & Resort             6
# 1166     6                   108  Viejas Casino & Resort             7
# 1167     6                   108  Viejas Casino & Resort             8
#
#             short_name   pop    pct
# 0             Hispanic  5306  26.96
# 1                White  8415  42.76
# 2                Black  1534   7.79
# 3      American Indian    93   0.47
# 4                Asian  3579  18.19
# ...                ...   ...    ...
# 1163   American Indian    11   2.04
# 1164             Asian    13   2.42
# 1165  Pacific Islander     1   0.19
# 1166             Other     2   0.37
# 1167       Two or More    20   3.72
#
# [1168 rows x 7 columns]

# %%
query = """
-- Housing Units by Structure Type
DECLARE	@return_value int

EXEC	@return_value = [employment_centers].[sp_housing_by_structure_type_by_center]
		@release_id = 2,
		@demographic_warehouse_datasource_id = 45,
		@year = 2021
"""

HU_by_Type_SQL =  pd.read_sql_query(query, conn)
HU_by_Type_SQL
# Out:
#      tier  employment_center_id  employment_center_name  structure_type_id  \
# 0       0                    80             Kearny Mesa                  1
# 1       0                    80             Kearny Mesa                  2
# 2       0                    80             Kearny Mesa                  3
# 3       0                    80             Kearny Mesa                  4
# 4       0                    80             Kearny Mesa                  5
# ..    ...                   ...                     ...                ...
# 871     6                   108  Viejas Casino & Resort                  2
# 872     6                   108  Viejas Casino & Resort                  3
# 873     6                   108  Viejas Casino & Resort                  4
# 874     6                   108  Viejas Casino & Resort                  5
# 875     6                   108  Viejas Casino & Resort                  6
#
#                          long_name  units    hh
# 0         Single Family - Detached   1010   984
# 1    Single Family - Multiple Unit    283   272
# 2                      Multifamily   5954  5735
# 3                      Mobile Home    325   297
# 4           Single-family Detached      0     0
# ..                             ...    ...   ...
# 871  Single Family - Multiple Unit      3     2
# 872                    Multifamily      0     0
# 873                    Mobile Home     34    33
# 874         Single-family Detached      0     0
# 875         Single-family Attached      0     0
#
# [876 rows x 7 columns]

# %%
query = """
-- Land Area (in square miles) 
DECLARE	@return_value int

EXEC	@return_value = [employment_centers].[sp_land_area]
		@release_id = 2
"""

EC_by_Land_Area_SQL =  pd.read_sql_query(query, conn)
EC_by_Land_Area_SQL
# Out:
#      release_id  employment_center_id  \
# 0             2                     1
# 1             2                     2
# 2             2                     3
# 3             2                     4
# 4             2                     5
# ..          ...                   ...
# 142           2                  1039
# 143           2                  1040
# 144           2                  1041
# 145           2                  1042
# 146           2                  1043
#
#                                 employment_center_name  tier  sq_miles
# 0                                    San Diego Airport     3      2.58
# 1                                               Alpine     4      2.67
# 2                                         Barrio Logan     4      0.81
# 3                             Carlsbad Palomar Airport     2      4.72
# 4                                 Carlsbad State Beach     3      1.57
# ..                                                 ...   ...       ...
# 142  Sorrento Valley West Sub-Center: Scripps_Research     0      2.52
# 143              Sorrento Valley West Sub-Center: UCSD     0      1.13
# 144  Sorrento Valley West Sub-Center: UCSD East Hea...     0      1.02
# 145        Sorrento Valley West Sub-Center: UTC Office     0      0.88
# 146        Sorrento Valley West Sub-Center: UTC Retail     0      0.12
#
# [147 rows x 5 columns]

# %% [markdown]
# ### Downloading the data from Excel

# %%
EC_by_Land_Area_excel = pd.read_excel(r'C:\Users\cra\San Diego Association of Governments\SANDAG QA QC - Documents\Projects\2023\2023-006 Employment Centers 2.0\data\EC2_Data_File_1_Build.xlsx', sheet_name='EC_by_Land_Area', header=2)
EC_by_Land_Area_excel = EC_by_Land_Area_excel.rename(columns={'Area_Sq_Mi':'sq_miles'})
EC_by_Land_Area_excel
# Out:
#      release_id  employment_center_id  \
# 0             2                     1
# 1             2                     2
# 2             2                     3
# 3             2                     4
# 4             2                     5
# ..          ...                   ...
# 142           2                  1039
# 143           2                  1040
# 144           2                  1041
# 145           2                  1042
# 146           2                  1043
#
#                                 employment_center_name  tier  sq_miles
# 0                                    San Diego Airport     3      2.58
# 1                                               Alpine     4      2.67
# 2                                         Barrio Logan     4      0.81
# 3                             Carlsbad Palomar Airport     2      4.72
# 4                                 Carlsbad State Beach     3      1.57
# ..                                                 ...   ...       ...
# 142  Sorrento Valley West Sub-Center: Scripps_Research     0      2.52
# 143              Sorrento Valley West Sub-Center: UCSD     0      1.13
# 144  Sorrento Valley West Sub-Center: UCSD East Hea...     0      1.02
# 145        Sorrento Valley West Sub-Center: UTC Office     0      0.88
# 146        Sorrento Valley West Sub-Center: UTC Retail     0      0.12
#
# [147 rows x 5 columns]

# %%
Pop_by_Type_excel = pd.read_excel(r'C:\Users\cra\San Diego Association of Governments\SANDAG QA QC - Documents\Projects\2023\2023-006 Employment Centers 2.0\data\EC2_Data_File_1_Build.xlsx', sheet_name='Pop_by_Type', header=2, usecols="A:F")
Pop_by_Type_excel
# Out:
#      tier  employment_center_id                       employment_center_name  \
# 0       3                     1                            San Diego Airport
# 1       3                     1                            San Diego Airport
# 2       3                     1                            San Diego Airport
# 3       3                     1                            San Diego Airport
# 4       4                     2                                       Alpine
# ..    ...                   ...                                          ...
# 579     0                  1042  Sorrento Valley West Sub-Center: UTC Office
# 580     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 581     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 582     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 583     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
#
#      housing_type_id                  long_name   pop
# 0                  1       Household Population  6294
# 1                  2  Group Quarters - Military    17
# 2                  3   Group Quarters - College     0
# 3                  4     Group Quarters - Other   229
# 4                  1       Household Population  4326
# ..               ...                        ...   ...
# 579                4     Group Quarters - Other     0
# 580                1       Household Population     0
# 581                2  Group Quarters - Military     0
# 582                3   Group Quarters - College     0
# 583                4     Group Quarters - Other     0
#
# [584 rows x 6 columns]

# %%
Pop_by_Age_excel = pd.read_excel(r'C:\Users\cra\San Diego Association of Governments\SANDAG QA QC - Documents\Projects\2023\2023-006 Employment Centers 2.0\data\EC2_Data_File_1_Build.xlsx', sheet_name='Pop_by_Age', header=2, usecols="A:F")
Pop_by_Age_excel
# Out:
#       tier  employment_center_id                       employment_center_name  \
# 0        3                     1                            San Diego Airport
# 1        3                     1                            San Diego Airport
# 2        3                     1                            San Diego Airport
# 3        3                     1                            San Diego Airport
# 4        3                     1                            San Diego Airport
# ...    ...                   ...                                          ...
# 2915     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 2916     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 2917     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 2918     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 2919     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
#
#       age_group_id     age_group  pop
# 0                1       Under 5  359
# 1                2        5 to 9  333
# 2                3      10 to 14  347
# 3                4      15 to 17  241
# 4                5     18 and 19  147
# ...            ...           ...  ...
# 2915            16      65 to 69    0
# 2916            17      70 to 74    0
# 2917            18      75 to 79    0
# 2918            19      80 to 84    0
# 2919            20  85 and Older    0
#
# [2920 rows x 6 columns]

# %%
Pop_by_Race_Eth_excel = pd.read_excel(r'C:\Users\cra\San Diego Association of Governments\SANDAG QA QC - Documents\Projects\2023\2023-006 Employment Centers 2.0\data\EC2_Data_File_1_Build.xlsx', sheet_name='Pop_by_Race-Eth', header=2, usecols="A:G")
Pop_by_Race_Eth_excel
# Out:
#       tier  employment_center_id                       employment_center_name  \
# 0        3                     1                            San Diego Airport
# 1        3                     1                            San Diego Airport
# 2        3                     1                            San Diego Airport
# 3        3                     1                            San Diego Airport
# 4        3                     1                            San Diego Airport
# ...    ...                   ...                                          ...
# 1163     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 1164     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 1165     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 1166     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 1167     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
#
#       ethnicity_id        short_name   pop    pct
# 0                1          Hispanic  1567  23.96
# 1                2             White  3896  59.57
# 2                3             Black   276   4.22
# 3                4   American Indian    28   0.43
# 4                5             Asian   439   6.71
# ...            ...               ...   ...    ...
# 1163             4   American Indian     0    NaN
# 1164             5             Asian     0    NaN
# 1165             6  Pacific Islander     0    NaN
# 1166             7             Other     0    NaN
# 1167             8       Two or More     0    NaN
#
# [1168 rows x 7 columns]

# %%
HU_by_Type_excel = pd.read_excel(r'C:\Users\cra\San Diego Association of Governments\SANDAG QA QC - Documents\Projects\2023\2023-006 Employment Centers 2.0\data\EC2_Data_File_1_Build.xlsx', sheet_name='HU_by_Type', header=2, usecols="A:G")
HU_by_Type_excel
# Out:
#      tier  employment_center_id                       employment_center_name  \
# 0       3                     1                            San Diego Airport
# 1       3                     1                            San Diego Airport
# 2       3                     1                            San Diego Airport
# 3       3                     1                            San Diego Airport
# 4       3                     1                            San Diego Airport
# ..    ...                   ...                                          ...
# 871     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 872     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 873     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 874     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
# 875     0                  1043  Sorrento Valley West Sub-Center: UTC Retail
#
#      structure_type_id                      long_name  units    hh
# 0                    1       Single Family - Detached    770   748
# 1                    2  Single Family - Multiple Unit    266   257
# 2                    3                    Multifamily   1748  1673
# 3                    4                    Mobile Home      0     0
# 4                    5         Single-family Detached      0     0
# ..                 ...                            ...    ...   ...
# 871                  2  Single Family - Multiple Unit      0     0
# 872                  3                    Multifamily      0     0
# 873                  4                    Mobile Home      0     0
# 874                  5         Single-family Detached      0     0
# 875                  6         Single-family Attached      0     0
#
# [876 rows x 7 columns]

# %% [markdown]
# ### Test For Equivalency

# %%
def compare_dataframes(sql_df, excel_df):
    if sql_df.shape != excel_df.shape:
        return False
    
    merged = sql_df.merge(excel_df, how='left', on=list(sql_df.columns))

    # If the DFs have the same data, then the merge will output an identically shaped dataframe 
    if merged.shape != sql_df.shape:
        return False
    
    
    return True

# %%
SQL_data = [EC_by_Land_Area_SQL,HU_by_Type_SQL,Pop_by_Race_Eth_SQL,Pop_by_Type_SQL,Pop_by_Age_SQL]
excel_data = [EC_by_Land_Area_excel,HU_by_Type_excel,Pop_by_Race_Eth_excel,Pop_by_Type_excel,Pop_by_Age_excel]

# %%
for i in range(0,len(SQL_data)):
    print(compare_dataframes(SQL_data[i], excel_data[i]))
# Out:
# True
# True
# True
# True
# True
