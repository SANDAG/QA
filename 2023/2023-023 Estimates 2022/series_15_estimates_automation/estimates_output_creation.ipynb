# %%
from mgra_denormalize_creation import create_and_merge_all_data

# %%
create_and_merge_all_data()
# Out:
#           mgra_id   mgra  census_tract  LUZ                    cpa  \
# 0      1500000100      1          2705   10  Mid-City:Eastern Area
# 1      1500000200      2          5601   28               Downtown
# 2      1500000300      3         15407  112         *Not in a CPA*
# 3      1500000400      4         17407  151         *Not in a CPA*
# 4      1500000500      5         17407  151         *Not in a CPA*
# ...           ...    ...           ...  ...                    ...
# 24316  1502431700  24317          2905   11         County Islands
# 24317  1502431800  24318         20706  133     North County Metro
# 24318  1502431900  24319         21001  225        Mountain Empire
# 24319  1502432000  24320         21002  224                 Desert
# 24320  1502432100  24321         20106  200         *Not in a CPA*
#
#          jurisdiction
# 0           San Diego
# 1           San Diego
# 2            El Cajon
# 3           Encinitas
# 4           Encinitas
# ...
