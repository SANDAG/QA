# %% [markdown]
# # Estimates Automation

# %%
# Standard library imports
import json
import sqlalchemy as sql
from pathlib import Path

# Local imports
import estimates_automation as ea

# %%
DDAM = sql.create_engine('mssql+pymssql://DDAMWSQL16')

CONFIG = None
with open("./config.json", "r") as f:
    CONFIG = json.load(f)

# %% [markdown]
# ## Aggregation by Geography Function

# %%
# Example usage
ea.get_table_by_geography(DDAM, CONFIG, "population", "region", pivot=True)
# Out:
#        region  yr_id  Total Population  Household Population  \
# 0   San Diego   2010           3095314               2993348
# 1   San Diego   2011           3125655               3023755
# 2   San Diego   2012           3161809               3058317
# 3   San Diego   2013           3199901               3098470
# 4   San Diego   2014           3232763               3127530
# 5   San Diego   2015           3265039               3156961
# 6   San Diego   2016           3285151               3177681
# 7   San Diego   2017           3306890               3200591
# 8   San Diego   2018           3326318               3215545
# 9   San Diego   2019           3340312               3230523
# 10  San Diego   2020           3343355               3230945
#
#     Group Quarters - Military  Group Quarters - College  \
# 0                       43597                     16055
# 1                       42309                     16968
# 2                       42539                     17540
# 3                       40622                     18316
# 4                       42313                     19046
# 5                       43732                     19357
# 6                       44193                     19160
# 7                       43280                     18989
# 8                       43995                     20178
# 9                       44257                     20208
# 10                      44770                     20282
#
#     Group Quarters - Other
# 0                    42314
# 1                    42623
# 2                    43413
# 3                    42493
# 4                    43874
# 5                    44989
# 6                    44117
# 7                    44030
# 8                    46600
# 9                    45324
# 10                   47358

# %%
# Example usage 2
ea.get_table_by_geography(DDAM, CONFIG, "age_sex_ethnicity", "jurisdiction", pivot=True)
# Out:
#      jurisdiction  yr_id          name     sex  Hispanic  Non-Hispanic, White  \
# 0        Carlsbad   2010      10 to 14  Female       668                 2377
# 1        Carlsbad   2010      10 to 14    Male       689                 2546
# 2        Carlsbad   2010      15 to 17  Female       399                 1397
# 3        Carlsbad   2010      15 to 17    Male       431                 1560
# 4        Carlsbad   2010     18 and 19  Female       172                  626
# ...           ...    ...           ...     ...       ...                  ...
# 8355        Vista   2020      80 to 84    Male       154                  462
# 8356        Vista   2020  85 and Older  Female       247                  853
# 8357        Vista   2020  85 and Older    Male       159                  484
# 8358        Vista   2020       Under 5  Female      1965                 1241
# 8359        Vista   2020       Under 5    Male      1964                 1184
#
#       Non-Hispanic, Asian  Non-Hispanic, Hawaiian or Pacific Islander  \
# 0                     212                                           7
# 1                     235                                           5
# 2                      99                                           4
# 3                     152                                           5
# 4                      41                                           1
# ...                   ...                                         ...
# 8355                   59                                           9
# 8356                   96                                           5
# 8357                   47                                           1
# 8358                  142                                           9
# 8359                  147                                          10
#
#       Non-Hispanic, American Indian or Alaska Native  Non-Hispanic, Other  \
# 0                                                 12                   14
# 1                                                 13                    6
# 2                                                  5                    4
# 3                                                  6                    8
# 4                                                  3                    1
# ...                                              ...                  ...
# 8355                                               3                    1
# 8356                                               7                    1
# 8357                                               3                    1
# 8358                                              17                    3
# 8359                                              15                    8
#
#       Non-Hispanic, Two or More Races  Non-Hispanic, Black
# 0                                 229                   38
# 1                                 244                   56
# 2                                 120                   30
# 3                                 111                   43
# 4                                  29                   15
# ...                               ...                  ...
# 8355                                8                   16
# 8356                                8                   19
# 8357                                7                   15
# 8358                              127                  133
# 8359                              154                  131
#
# [8360 rows x 12 columns]

# %%
# Example usage 3
ea.get_table_by_geography(DDAM, CONFIG, "age_ethnicity", "cpa", pivot=True)
# Out:
#                            cpa  yr_id          name  Hispanic  \
# 0               *Not in a CPA*   2010      10 to 14     46150
# 1               *Not in a CPA*   2010      15 to 17     29252
# 2               *Not in a CPA*   2010     18 and 19     19093
# 3               *Not in a CPA*   2010      20 to 24     43737
# 4               *Not in a CPA*   2010      25 to 29     40426
# ...                        ...    ...           ...       ...
# 19575  Via De La Valle Reserve   2020      70 to 74         0
# 19576  Via De La Valle Reserve   2020      75 to 79         0
# 19577  Via De La Valle Reserve   2020      80 to 84         0
# 19578  Via De La Valle Reserve   2020  85 and Older         0
# 19579  Via De La Valle Reserve   2020       Under 5         0
#
#        Non-Hispanic, American Indian or Alaska Native  Non-Hispanic, Asian  \
# 0                                                 261                 5914
# 1                                                 179                 3607
# 2                                                 138                 2255
# 3                                                 463                 6552
# 4                                                 396                 7125
# ...                                               ...                  ...
# 19575                                               0                    0
# 19576                                               0                    0
# 19577                                               0                    0
# 19578                                               0                    0
# 19579                                               0                    0
#
#        Non-Hispanic, Black  Non-Hispanic, Hawaiian or Pacific Islander  \
# 0                     3026                                         403
# 1                     2156                                         291
# 2                     1595                                         228
# 3                     5030                                         591
# 4                     4494                                         563
# ...                    ...                                         ...
# 19575                    0                                           0
# 19576                    0                                           0
# 19577                    0                                           0
# 19578                    0                                           0
# 19579                    0                                           0
#
#        Non-Hispanic, Other  Non-Hispanic, Two or More Races  \
# 0                      209                             4480
# 1                      142                             2684
# 2                       72                             1521
# 3                      210                             3526
# 4                      199                             2883
# ...                    ...                              ...
# 19575                    0                                0
# 19576                    0                                0
# 19577                    0                                0
# 19578                    0                                0
# 19579                    0                                0
#
#        Non-Hispanic, White
# 0                    30856
# 1                    20273
# 2                    13481
# 3                    40763
# 4                    39832
# ...                    ...
# 19575                    0
# 19576                    0
# 19577                    0
# 19578                    0
# 19579                    0
#
# [19580 rows x 11 columns]

# %% [markdown]
# ## Consolidated Files

# %%
# Example usage
# Note, geo_list and est_table_list are optional parameters as they both have default values
# Also, this is only showing the jurisdiction table (index [1])
ea.consolidate(DDAM, CONFIG)[1]
# Out:
#     jurisdiction  yr_id  Under 5  5 to 9  10 to 14  15 to 17  18 and 19  \
# 0       Carlsbad   2010     6236    7225      7351      4374       2047
# 1       Carlsbad   2011     6118    6981      7372      4510       2464
# 2       Carlsbad   2012     6070    6930      7276      4650       2675
# 3       Carlsbad   2013     6207    6694      7229      4684       2721
# 4       Carlsbad   2014     6297    6706      7049      4724       2718
# ..           ...    ...      ...     ...       ...       ...        ...
# 204        Vista   2016     7621    8121      7259      4671       2952
# 205        Vista   2017     7649    8329      7664      4782       2903
# 206        Vista   2018     7485    8324      7860      4851       2893
# 207        Vista   2019     7364    8264      8038      4810       2939
# 208        Vista   2020     7250    8373      8154      4901       2943
#
#      20 to 24  25 to 29  30 to 34  ...  unoccupiable  occupied  vacancy  \
# 0        4806      5986      6348  ...          2147     41345     2884
# 1        5387      6025      6464  ...          2140     41608     2873
# 2        6018      6009      6626  ...          2140     41893     2998
# 3        6593      6102      6779  ...          2140     42251     2891
# 4        7068      6121      6876  ...          2140     42673     2889
# ..        ...       ...       ...  ...           ...       ...      ...
# 204      7488      6683      7125  ...           696     30242     1200
# 205      8165      6819      7068  ...           695     31110     1085
# 206      7867      6819      6779  ...           695     31178     1091
# 207      7933      6699      6513  ...           695     31255     1101
# 208      8287      6781      6317  ...           695     31537      963
#
#      Total Population  Household Population  Group Quarters - Military  \
# 0              105328                104413                          0
# 1              106768                105853                          0
# 2              108272                107357                          0
# 3              109655                108740                          0
# 4              111117                110202                          0
# ..                ...                   ...                        ...
# 204             99135                 97084                          0
# 205            101879                 99820                          0
# 206            101984                 99861                          0
# 207            102098                 99956                          0
# 208            102928                100814                          0
#
#      Group Quarters - College  Group Quarters - Other  Female   Male
# 0                           0                     915   53736  51592
# 1                           0                     915   54437  52331
# 2                           0                     915   55193  53079
# 3                           0                     915   55752  53903
# 4                           0                     915   56456  54661
# ..                        ...                     ...     ...    ...
# 204                         0                    2051   49492  49643
# 205                         0                    2059   50811  51068
# 206                         0                    2123   50789  51195
# 207                         0                    2142   50918  51180
# 208                         0                    2114   51288  51640
#
# [209 rows x 58 columns]

# %%
# # Example usage with saving
# # Note: Commented out to avoid accidentally running
# user = "eli"
# save_location = Path(f"C:/Users/{user}/San Diego Association of Governments/SANDAG QA QC - Documents/Projects/2022/2022-56 Estimates 2021 QC/Data/")
# _ = ea.consolidate(DDAM, CONFIG, save=True, save_folder=save_location) # "_ = " to ignore return values

# %% [markdown]
# ## Individual Files

# %%
# Example usage 1
x = ea.individual(DDAM, CONFIG, geo_list=["region", "jurisdiction"], 
        est_table_list=["age", "ethnicity", "age_ethnicity"])
x[0]
# Out:
#        region  yr_id  Under 5  5 to 9  10 to 14  15 to 17  18 and 19  \
# 0   San Diego   2010   203423  194029    198716    128000      97095
# 1   San Diego   2011   209818  197773    198866    128833      95984
# 2   San Diego   2012   215677  203754    198403    131596      97211
# 3   San Diego   2013   219753  210910    199295    133282      98736
# 4   San Diego   2014   222064  216798    200875    132669     100101
# 5   San Diego   2015   223824  221252    202795    131361     101520
# 6   San Diego   2016   223355  224985    205244    131064     100003
# 7   San Diego   2017   221684  228181    210062    131314      98316
# 8   San Diego   2018   219100  229534    215718    131683      98570
# 9   San Diego   2019   213921  230600    220580    132502      99494
# 10  San Diego   2020   206650  231838    223917    133979      99197
#
#     20 to 24  25 to 29  30 to 34  ...  45 to 49  50 to 54  55 to 59  \
# 0     270750    250737    220185  ...    219795    210980    180305
# 1     269851    246589    224827  ...    216967    213219    185244
# 2     267545    240615    230265  ...    213155    215234    191186
# 3     265080    234627    235654  ...    210161    216585    196575
# 4     263770    228231    240016  ...    208012    217419    200838
# 5     263884    222382    240792  ...    208056    216930    204873
# 6     263975    218370    236207  ...    209433    213627    207778
# 7     264924    215777    230157  ...    210993    209507    209560
# 8     264797    212733    223717  ...    210974    205816    210362
# 9     263897    210274    216586  ...    209194    202841    210308
# 10    262827    207950    209086  ...    205744    201350    208035
#
#     60 and 61  62 to 64  65 to 69  70 to 74  75 to 79  80 to 84  85 and Older
# 0       64088     85223    103241     77313     64347     52564         53960
# 1       65395     90092    108198     80080     64763     53044         55169
# 2       66248     94222    116570     83765     65707     53304         56304
# 3       68049     96238    125993     88669     67357     53490         57184
# 4       71049     97916    134674     93526     69690     53723         58123
# 5       74316     99943    143500     98097     72596     54019         59542
# 6       76690    102855    150812    103135     75248     54291         60744
# 7       78084    107170    155161    110605     78080     55166         61590
# 8       79111    111109    157987    119302     81773     56630         62017
# 9       79972    113816    161640    127146     85638     58576         63080
# 10      81030    115084    165499    134497     89201     60700         64924
#
# [11 rows x 22 columns]

# %%
# Example usage 2
ea.individual(DDAM, CONFIG, geo_list=["jurisdiction"], 
    est_table_list=["housing"])[0]
# Out:
#     jurisdiction  yr_id  Single Family - Detached  \
# 0       Carlsbad   2010                     23359
# 1       Carlsbad   2011                     23534
# 2       Carlsbad   2012                     23802
# 3       Carlsbad   2013                     24025
# 4       Carlsbad   2014                     24337
# ..           ...    ...                       ...
# 204        Vista   2016                     15348
# 205        Vista   2017                     15392
# 206        Vista   2018                     15496
# 207        Vista   2019                     15534
# 208        Vista   2020                     15589
#
#      Single Family - Multiple Unit  Multifamily  Mobile Home  \
# 0                             6350        13221         1299
# 1                             6402        13231         1314
# 2                             6464        13311         1314
# 3                             6489        13314         1314
# 4                             6549        13361         1315
# ..                             ...          ...          ...
# 204                           2331        11765         1998
# 205                           2335        12470         1998
# 206                           2351        12424         1998
# 207                           2358        12466         1998
# 208                           2363        12550         1998
#
#      Single-family Detached  Single-family Attached  units  unoccupiable  \
# 0                         0                       0  44229          2147
# 1                         0                       0  44481          2140
# 2                         0                       0  44891          2140
# 3                         0                       0  45142          2140
# 4                         0                       0  45562          2140
# ..                      ...                     ...    ...           ...
# 204                       0                       0  31442           696
# 205                       0                       0  32195           695
# 206                       0                       0  32269           695
# 207                       0                       0  32356           695
# 208                       0                       0  32500           695
#
#      occupied  vacancy
# 0       41345     2884
# 1       41608     2873
# 2       41893     2998
# 3       42251     2891
# 4       42673     2889
# ..        ...      ...
# 204     30242     1200
# 205     31110     1085
# 206     31178     1091
# 207     31255     1101
# 208     31537      963
#
# [209 rows x 12 columns]

# %%
# # Example usage with saving
# # Note: Commented out to avoid accidentally running
# user = "eli"
# save_location = Path(f"C:/Users/{user}/San Diego Association of Governments/SANDAG QA QC - Documents/Projects/2022/2022-56 Estimates 2021 QC/Data/")
# _ = individual(DDAM, CONFIG, save=True, save_folder=save_location) # "_ = " to ignore return values
