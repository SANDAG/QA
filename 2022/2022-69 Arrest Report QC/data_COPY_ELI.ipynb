# %%
import pandas as pd

# %% [markdown]
# ### Data Columns
#
# The data extract did not come with columns, so those are defined below.

# %%
columns = [
    'Act-Pk',
    'ActivityNumber',
    'ActivityType',
    'activitySubType',
    'agency',
    'activityDate',
    'Per_Role',
    'DOB',
    'Age',
    'Gender',
    'Race',	
    'highest_violationSection',
    'highest_violationType',
    'highest_chargeCategory',
    'highest_chargeDescription',
    'highest_codeBcsClass',
    'highest_codeBcsCategory',
    'highest_chargeLevel',	
    'macrDisposition',
    'macrIndicationLevel',
    'macrJuvenileLevel',
    'macrStatus1',
    'codeBcsCategory',
    'codeBcsClass',
    'codeUcr',
    'CrimeCategory',
    'CrimeDescription',
    'Loc_Role',
    'city',
    'zipCode',
    'censusBlock',
    'censusTract',
    'BCSCode',
    'MACRCode',
    'BCSDesc',
    'MACRDesc',
    'macrStatus',
    'dispositionCode',
    'bcsClassCode',
    'reportYear',
    'reportMonth',
    'BCAArea',
]

# %% [markdown]
# ### Merging the two extracts
#
# We had to send multiple data requests to get everything we need. The first new pull we got Race/Ethnicity but didn't get BCAArea, the second pull we got BCAArea but didn't get Race/Ethnicity. Anything with 9_20 at the end was the second pull.
#
# They also came in separate files, so we have to merge them all together.
#
# The cell below uses the one without Race/Ethnicity as the left table, and joins the other as the right table.
#
# The order was the same, so we can just exclude the column that was missing in both.

# %%
import pathlib

base_path = pathlib.Path("C:/Users/eli/OneDrive - San Diego Association of Governments/Documents - SANDAG QA_QC/Service Requests/2022/2022-69 Arrest Report QC/data/")

ldf = pd.concat([
    pd.read_csv(base_path / "Arrest Bulletin Data 2016 09_20.txt", delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
    pd.read_csv(base_path / 'Arrest Bulletin Data 2017 09_20.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
    pd.read_csv(base_path / 'Arrest Bulletin Data 2018 09_20.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
    pd.read_csv(base_path / 'Arrest Bulletin Data 2019 09_20.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
    pd.read_csv(base_path / 'Arrest Bulletin Data 2020 09_20.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
    pd.read_csv(base_path / 'Arrest Bulletin Data 2021 09_20.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
])
ldf = ldf.drop("Race", axis=1)

# %%
rdf = pd.concat([
    pd.read_csv(base_path / 'Arrest Bulletin Data 2016_17.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
    pd.read_csv(base_path / 'Arrest Bulletin Data 2018_19.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
    pd.read_csv(base_path / 'Arrest Bulletin Data 2020.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
    pd.read_csv(base_path / 'Arrest Bulletin Data 2021.txt', delimiter='\t', dtype='string[pyarrow]',header=None, names=columns),
])
rdf = rdf.drop("BCAArea", axis=1)

# %%
ldf.columns
# Out:
# Index(['Act-Pk', 'ActivityNumber', 'ActivityType', 'activitySubType', 'agency',
#        'activityDate', 'Per_Role', 'DOB', 'Age', 'Gender',
#        'highest_violationSection', 'highest_violationType',
#        'highest_chargeCategory', 'highest_chargeDescription',
#        'highest_codeBcsClass', 'highest_codeBcsCategory',
#        'highest_chargeLevel', 'macrDisposition', 'macrIndicationLevel',
#        'macrJuvenileLevel', 'macrStatus1', 'codeBcsCategory', 'codeBcsClass',
#        'codeUcr', 'CrimeCategory', 'CrimeDescription', 'Loc_Role', 'city',
#        'zipCode', 'censusBlock', 'censusTract', 'BCSCode', 'MACRCode',
#        'BCSDesc', 'MACRDesc', 'macrStatus', 'dispositionCode', 'bcsClassCode',
#        'reportYear', 'reportMonth', 'BCAArea'],
#       dtype='object')

# %%
ldf.head()
# Out:
#      Act-Pk ActivityNumber ActivityType activitySubType         agency  \
# 0  12162665   '16-0008601'       ARREST           ADULT  HARBOR POLICE
# 1  12162512   '15-0609601'       ARREST           ADULT  HARBOR POLICE
# 2  12125654   '1610003101'       ARREST           ADULT        SHERIFF
# 3  12141169   '1600000101'       ARREST           ADULT      ESCONDIDO
# 4  12125886   '1610000001'       ARREST           ADULT        SHERIFF
#
#               activityDate Per_Role         DOB Age  Gender  ...     BCSCode  \
# 0  2016-01-01 00:01:00.000  SUSPECT  1961/12/03  54  FEMALE  ...  M02
# 1  2016-01-01 00:01:00.000  SUSPECT  1961/12/03  54  FEMALE  ...  M02
# 2  2016-01-01 00:05:00.000  SUSPECT  1966/06/02  49    MALE  ...  F19
# 3  2016-01-01 00:05:00.000  SUSPECT  1964/05/29  51    MALE  ...  M18
# 4  2016-01-01 00:06:00.000  SUSPECT  1958/01/25  57    MALE  ...  M14
#
#                  MACRCode              BCSDesc MACRDesc macrStatus  \
# 0                 BATTERY  ASSAULT AND BATTERY        3          3
# 1                 BATTERY  ASSAULT AND BATTERY     <NA>       <NA>
# 2      PROHIBITED WEAPONS              WEAPONS        3          4
# 3  TAMPERING WITH VEHICLE            VANDALISM        3          3
# 4                   DRUNK      DRUNK: PROT/CUS        3          3
#
#   dispositionCode bcsClassCode reportYear  \
# 0             397         2016         01
# 1            <NA>         <NA>       <NA>
# 2             844         2016         01
# 3             066         2016         01
# 4             046         2016         01
#
#                                 reportMonth BCAArea
# 0                                      <NA>    <NA>
# 1                                      <NA>    <NA>
# 2                                      <NA>    <NA>
# 3                                      <NA>    <NA>
# 4  CITY OF LEMON GROVE                         <NA>
#
# [5 rows x 41 columns]

# %%
rdf.columns
# Out:
# Index(['Act-Pk', 'ActivityNumber', 'ActivityType', 'activitySubType', 'agency',
#        'activityDate', 'Per_Role', 'DOB', 'Age', 'Gender', 'Race',
#        'highest_violationSection', 'highest_violationType',
#        'highest_chargeCategory', 'highest_chargeDescription',
#        'highest_codeBcsClass', 'highest_codeBcsCategory',
#        'highest_chargeLevel', 'macrDisposition', 'macrIndicationLevel',
#        'macrJuvenileLevel', 'macrStatus1', 'codeBcsCategory', 'codeBcsClass',
#        'codeUcr', 'CrimeCategory', 'CrimeDescription', 'Loc_Role', 'city',
#        'zipCode', 'censusBlock', 'censusTract', 'BCSCode', 'MACRCode',
#        'BCSDesc', 'MACRDesc', 'macrStatus', 'dispositionCode', 'bcsClassCode',
#        'reportYear', 'reportMonth'],
#       dtype='object')

# %%
rdf.head()
# Out:
#      Act-Pk ActivityNumber ActivityType activitySubType         agency  \
# 0  12162665   '16-0008601'       ARREST           ADULT  HARBOR POLICE
# 1  12162512   '15-0609601'       ARREST           ADULT  HARBOR POLICE
# 2  12125654   '1610003101'       ARREST           ADULT        SHERIFF
# 3  12141169   '1600000101'       ARREST           ADULT      ESCONDIDO
# 4  12125886   '1610000001'       ARREST           ADULT        SHERIFF
#
#               activityDate Per_Role         DOB Age  Gender  ... censusTract  \
# 0  2016-01-01 00:01:00.000  SUSPECT  1961/12/03  54  FEMALE  ...      007100
# 1  2016-01-01 00:01:00.000  SUSPECT  1961/12/03  54  FEMALE  ...      007100
# 2  2016-01-01 00:05:00.000  SUSPECT  1966/06/02  49    MALE  ...        <NA>
# 3  2016-01-01 00:05:00.000  SUSPECT  1964/05/29  51    MALE  ...      020308
# 4  2016-01-01 00:06:00.000  SUSPECT  1958/01/25  57    MALE  ...      014400
#
#       BCSCode    MACRCode                 BCSDesc             MACRDesc  \
# 0  397         M02                        BATTERY  ASSAULT AND BATTERY
# 1  397         M02                        BATTERY  ASSAULT AND BATTERY
# 2  844         F19             PROHIBITED WEAPONS              WEAPONS
# 3  066         M18         TAMPERING WITH VEHICLE            VANDALISM
# 4  046         M14                          DRUNK      DRUNK: PROT/CUS
#
#   macrStatus dispositionCode bcsClassCode reportYear reportMonth
# 0          3               3          397       2016          01
# 1       <NA>            <NA>         <NA>       <NA>        <NA>
# 2          3               4          844       2016          01
# 3          3               3          066       2016          01
# 4          3               3          046       2016          01
#
# [5 rows x 41 columns]

# %% [markdown]
# So it's not a perfect merge, but as shown below only one record would really be affected.
#
# We could manually pull that record and manually make sure we record the first with Hispanic and the second with other.

# %%
# Count all occurances of this compound key, and only show anything > 1
ldf.groupby(['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'])['Act-Pk'].size().sort_values(ascending=False)[lambda x: x>1]
# Out:
# Act-Pk    ActivityNumber  activityDate             Gender     DOB
# 19666800  '19-1105'       2019-05-17 00:00:00.000  NONBINARY  1972/08/29    2
# 19069112  '16-0978'       2016-05-15 00:00:00.000  MALE       1990/06/29    2
# 20315656  '16-2868'       2016-12-31 15:28:00.000  MALE       1996/07/30    2
# Name: Act-Pk, dtype: int64

# %%
print(
    'Races of 19069112 duplicate:',
    rdf.groupby(['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'])['Race'].first().loc[('19069112', "'16-0978'", '2016-05-15 00:00:00.000', 'MALE', '1990/06/29')],
    rdf.groupby(['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'])['Race'].last().loc[('19069112', "'16-0978'", '2016-05-15 00:00:00.000', 'MALE', '1990/06/29')],
)

print(
    'Races of 19666800 duplicate:',
    rdf.groupby(['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'])['Race'].first().loc[('19666800', "'19-1105'", '2019-05-17 00:00:00.000', 'NONBINARY', '1972/08/29')],
    rdf.groupby(['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'])['Race'].last().loc[('19666800', "'19-1105'", '2019-05-17 00:00:00.000', 'NONBINARY', '1972/08/29')],
)

print(
    'Races of 20315656 duplicate:',
    rdf.groupby(['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'])['Race'].first().loc[('20315656', "'16-2868'", '2016-12-31 15:28:00.000', 'MALE', '1996/07/30')],
    rdf.groupby(['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'])['Race'].last().loc[('20315656', "'16-2868'", '2016-12-31 15:28:00.000', 'MALE', '1996/07/30')],
)
# Out:
# Races of 19069112 duplicate: HISPANIC OTHER
# Races of 19666800 duplicate: OTHER OTHER
# Races of 20315656 duplicate: WHITE WHITE

# %% [markdown]
# Cell below actually performs the merge.

# %%
# Drop the 3 duplicated keys on the right table.
# So we only have a single one for the merge.
rdf = rdf[~rdf.duplicated(['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'])]

# %%
# Merge the right dataframe with Race/Ethnicity onto the left dataframe without it, using the key we discussed above.
ldf['Race'] = ldf.merge(
    rdf,
    on=['Act-Pk', 'ActivityNumber', 'activityDate', 'Gender', 'DOB'],
)['Race']

# %%
# The number of individual arrests reported for each year.
ldf['reportYear'].value_counts()
# Out:
# 08    41057
# 10    41015
# 01    40660
# 03    40431
# 09    40293
# 07    39624
# 02    39161
# 05    38414
# 04    37921
# 06    37777
# 11    36499
# 12    35249
# Name: reportYear, dtype: Int64

# %%
# This was tried earlier to fix an issue, but may be unecessary.
# I *think* MS SQL reads "NULL" as NULL on import, so I manually coded anything that was pandas <NA> into the string "NULL"

from tqdm.auto import tqdm
tqdm.pandas()

for column in tqdm([
        'highest_codeBcsClass',
        'highest_codeBcsCategory',
        'BCSDesc',
        'macrStatus',
        'highest_chargeLevel',
        'censusBlock',
        'censusTract',
        'MACRCode',
        'MACRDesc',
        'macrStatus',
        'Gender',
        'codeUcr',
        'CrimeCategory',
        'CrimeDescription',
        'highest_chargeCategory',
        'BCAArea',
        'Race',
    ]):
    ldf[column] = ldf[column].progress_apply(lambda x: 'NULL' if pd.isna(x) else x)
# Out:
# 100%|██████████| 1314449/1314449 [00:01<00:00, 779639.69it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 825932.77it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 789447.23it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 790760.37it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 880786.95it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 868946.21it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 778378.59it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 696109.63it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 707675.00it/s]
# 100%|██████████| 1314449/1314449 [00:02<00:00, 636566.79it/s]
# 100%|██████████| 1314449/1314449 [00:02<00:00, 621839.52it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 815108.44it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 773772.93it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 850259.31it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 709846.93it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 925093.41it/s]
# 100%|██████████| 1314449/1314449 [00:01<00:00, 824984.95it/s]
# 100%|██████████| 17/17 [00:29<00:00,  1.72s/it]

# %%
ldf['highest_codeBcsClass'] = ldf['highest_codeBcsClass'].str.strip("'")

# %%
ldf['MACRCode'] = ldf['MACRCode'].str.strip()

# %%
ldf['Race'] = ldf['Race'].str.strip()

# %%
local = pathlib.Path("./data/")
ldf.to_csv(local / 'CJ_extract_2021.csv', header=None, index=None, sep='\t')
ldf.to_csv(local / 'CJ_extract_2021_header.csv', index=None, sep=',')

# %%
ldf.iloc[5-1, 0:16-1]
# Out:
# Act-Pk                                                                12125886
# ActivityNumber                                                    '1610000001'
# ActivityType                                                            ARREST
# activitySubType                                                          ADULT
# agency                                                                 SHERIFF
# activityDate                                           2016-01-01 00:06:00.000
# Per_Role                                                               SUSPECT
# DOB                                                                 1958/01/25
# Age                                                                         57
# Gender                                                                    MALE
# highest_violationSection                                                    PC
# highest_violationType                                       OTHER PART 2 CRIME
# highest_chargeCategory       DRUNK IN PUBLIC: ALCOHOL, DRUGS, COMBO OR TOLU...
# highest_chargeDescription                                                '046'
# highest_codeBcsClass                                                         A
# Name: 4, dtype: object

# %%
dfc = pd.read_csv(local / 'CJ_extract_2021_header.csv', keep_default_na=False)

# %%
dfc
# Out:
#            Act-Pk ActivityNumber ActivityType activitySubType         agency  \
# 0        12162665   '16-0008601'       ARREST           ADULT  HARBOR POLICE
# 1        12162512   '15-0609601'       ARREST           ADULT  HARBOR POLICE
# 2        12125654   '1610003101'       ARREST           ADULT        SHERIFF
# 3        12141169   '1600000101'       ARREST           ADULT      ESCONDIDO
# 4        12125886   '1610000001'       ARREST           ADULT        SHERIFF
# ...           ...            ...          ...             ...            ...
# 1314444  20826658   '2200003901'       ARREST           ADULT      SAN DIEGO
# 1314445  20831732   '2101749101'       ARREST           ADULT      OCEANSIDE
# 1314446  20837514   '22-0000201'       ARREST           ADULT  HARBOR POLICE
# 1314447  20825713   '2115682501'       ARREST           ADULT        SHERIFF
# 1314448  20886208    '211647801'       ARREST           ADULT    CHULA VISTA
#
#                     activityDate Per_Role         DOB Age  Gender  ...  \
# 0        2016-01-01 00:01:00.000  SUSPECT  1961/12/03  54  FEMALE  ...
# 1        2016-01-01 00:01:00.000  SUSPECT  1961/12/03  54  FEMALE  ...
# 2        2016-01-01 00:05:00.000  SUSPECT  1966/06/02  49    MALE  ...
# 3        2016-01-01 00:05:00.000  SUSPECT  1964/05/29  51    MALE  ...
# 4        2016-01-01 00:06:00.000  SUSPECT  1958/01/25  57    MALE  ...
# ...                          ...      ...         ...  ..     ...  ...
# 1314444  2021-12-31 23:50:00.000  SUSPECT  1998/06/12  23    MALE  ...
# 1314445  2021-12-31 23:50:00.000  SUSPECT  1974/07/21  47    MALE  ...
# 1314446  2021-12-31 23:54:00.000  SUSPECT  1993/09/06  28    MALE  ...
# 1314447  2021-12-31 23:57:00.000  SUSPECT  1995/11/20  26    MALE  ...
# 1314448  2021-12-31 23:58:00.000  SUSPECT  1990/12/09  31    MALE  ...
#
#                             MACRCode              BCSDesc MACRDesc macrStatus  \
# 0                            BATTERY  ASSAULT AND BATTERY        3          3
# 1                            BATTERY  ASSAULT AND BATTERY     NULL       NULL
# 2                 PROHIBITED WEAPONS              WEAPONS        3          4
# 3             TAMPERING WITH VEHICLE            VANDALISM        3          3
# 4                              DRUNK      DRUNK: PROT/CUS        3          3
# ...                              ...                  ...      ...        ...
# 1314444                        DRUNK      DRUNK: PROT/CUS        3          1
# 1314445          VISITING-SCHED I-II          OTHER DRUGS        1          3
# 1314446                         NULL                 NULL     NULL       NULL
# 1314447  THREATEN/ASSAULT AN OFFICER              ASSAULT        2          4
# 1314448                DRUNK DRIVING               D.U.I.        2          3
#
#         dispositionCode bcsClassCode reportYear  \
# 0                   397         2016         01
# 1
# 2                   844         2016         01
# 3                   066         2016         01
# 4                   046         2016         01
# ...                 ...          ...        ...
# 1314444             046         2021         12
# 1314445             818         2021         12
# 1314446
# 1314447             345         2021         12
# 1314448             856         2022         01
#
#                                       reportMonth BCAArea      Race
# 0                                                    NULL     WHITE
# 1                                                    NULL     WHITE
# 2                                                    NULL     BLACK
# 3                                                    NULL     WHITE
# 4        CITY OF LEMON GROVE                         NULL  HISPANIC
# ...                                           ...     ...       ...
# 1314444                                              NULL     OTHER
# 1314445                                              NULL     WHITE
# 1314446                                              NULL  HISPANIC
# 1314447                                              NULL  HISPANIC
# 1314448                                              NULL     OTHER
#
# [1314449 rows x 42 columns]

# %%
dfc[['highest_codeBcsClass', 'highest_codeBcsCategory', 'BCSDesc']]
# Out:
#         highest_codeBcsClass highest_codeBcsCategory              BCSDesc
# 0                          4             MISDEMEANOR  ASSAULT AND BATTERY
# 1                          4             MISDEMEANOR  ASSAULT AND BATTERY
# 2                          D                  FELONY              WEAPONS
# 3                          M             MISDEMEANOR            VANDALISM
# 4                          A             MISDEMEANOR      DRUNK: PROT/CUS
# ...                      ...                     ...                  ...
# 1314444                    A             MISDEMEANOR      DRUNK: PROT/CUS
# 1314445                    N             MISDEMEANOR          OTHER DRUGS
# 1314446                    A                   OTHER                 NULL
# 1314447                    4                  FELONY              ASSAULT
# 1314448                    A             MISDEMEANOR               D.U.I.
#
# [1314449 rows x 3 columns]

# %%
rdf.iloc[:, 10]
# Out:
# 0              WHITE
# 1              WHITE
# 2              BLACK
# 3              WHITE
# 4           HISPANIC
#              ...
# 183008         WHITE
# 183009         WHITE
# 183010         WHITE
# 183011         WHITE
# 183012    VIETNAMESE
# Name: Race, Length: 1648557, dtype: string

# %%
groups = list(dfc[
    [
        'codeUcr',
        'CrimeCategory',
        'CrimeDescription',
        'highest_chargeCategory',

    ]
].groupby([
        'codeUcr',
        'CrimeCategory',
        'CrimeDescription',
        'highest_chargeCategory',
]).groups)

# %%
dfc['agency'].unique()
# Out:
# array(['HARBOR POLICE', 'SHERIFF', 'ESCONDIDO', 'SAN DIEGO',
#        'CHULA VISTA', 'OCEANSIDE', 'CARLSBAD', 'NATIONAL CITY', 'LA MESA',
#        'EL CAJON', 'SYCUAN TRIBAL POLICE DEPARTMENT', 'CORONADO',
#        'SD STATE UNIV.', 'SW COMM COL PD', 'MTS POLICE', 'SD COMM COL PD',
#        'DISTRICT ATTORNEY'], dtype=object)

# %%
groups = list(dfc[
    [
        'highest_codeBcsClass',
        'highest_codeBcsCategory',
        'BCSDesc',
    ]
].groupby([
        'highest_codeBcsClass',
        'highest_codeBcsCategory',
        'BCSDesc',
]).groups)

# %%
groups
# Out:
# [('1', 'FELONY', 'MANSLAUGHTER NONVEH'),
#  ('1', 'FELONY', 'WILLFUL HOMICIDE'),
#  ('1', 'OTHER', 'WILLFUL HOMICIDE'),
#  ('2', 'FELONY', 'FORCIBLE RAPE'),
#  ('2H', 'FELONY', 'OTHER SEX'),
#  ('2N', 'FELONY', 'ANNOY CHILD'),
#  ('2N', 'FELONY', 'FORCIBLE RAPE'),
#  ('2N', 'FELONY', 'LEWD CONDUCT'),
#  ('2N', 'FELONY', 'LEWD OR LASCIVIOUS'),
#  ('2N', 'FELONY', 'OTHER SEX'),
#  ('3', 'FELONY', 'KIDNAPPING'),
#  ('3', 'FELONY', 'OTHER FELONY'),
#  ('3', 'FELONY', 'ROBBERY'),
#  ('4', 'FELONY', 'ASSAULT'),
#  ('4', 'FELONY', 'ASSAULT AND BATTERY'),
#  ('4', 'FELONY', 'ESCAPE'),
#  ('4', 'FELONY', 'LEWD OR LASCIVIOUS'),
#  ('4', 'FELONY', 'MANSLAUGHTER NONVEH'),
#  ('4', 'FELONY', 'OTHER FELONY'),
#  ('4', 'FELONY', 'OTHER SEX'),
#  ('4', 'MISDEMEANOR', 'ASSAULT AND BATTERY'),
#  ('4', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('4', 'MISDEMEANOR', 'PETTY THEFT'),
#  ('4', 'OTHER', 'NULL'),
#  ('5', 'FELONY', 'BURGLARY'),
#  ('5', 'MISDEMEANOR', 'PETTY THEFT'),
#  ('6', 'FELONY', 'THEFT'),
#  ('6', 'MISDEMEANOR', 'JOY RIDING'),
#  ('6', 'MISDEMEANOR', 'MALICIOUS MISCHIEF'),
#  ('6', 'MISDEMEANOR', 'PETTY THEFT'),
#  ('7', 'FELONY', 'MOTOR VEHICLE THEFT'),
#  ('7', 'MISDEMEANOR', 'JOY RIDING'),
#  ('8', 'FELONY', 'ARSON'),
#  ('8', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('A', 'FELONY', 'ARSON'),
#  ('A', 'FELONY', 'ASSAULT'),
#  ('A', 'FELONY', 'D.U.I.'),
#  ('A', 'FELONY', 'ESCAPE'),
#  ('A', 'FELONY', 'HIT & RUN'),
#  ('A', 'FELONY', 'KIDNAPPING'),
#  ('A', 'FELONY', 'MANSLAUGHTER VEH'),
#  ('A', 'FELONY', 'MARIJUANA'),
#  ('A', 'FELONY', 'OTHER DRUGS'),
#  ('A', 'FELONY', 'OTHER FELONY'),
#  ('A', 'FELONY', 'OTHER SEX'),
#  ('A', 'FELONY', 'THEFT'),
#  ('A', 'FELONY', 'WEAPONS'),
#  ('A', 'INFRACTION', 'CI/CO ORDINANCE'),
#  ('A', 'INFRACTION', 'LIQUOR LAWS'),
#  ('A', 'INFRACTION', 'MARIJUANA'),
#  ('A', 'INFRACTION', 'NULL'),
#  ('A', 'INFRACTION', 'OTHER MISDEMEANOR'),
#  ('A', 'MISDEMEANOR', 'ASSAULT AND BATTERY'),
#  ('A', 'MISDEMEANOR', 'CI/CO ORDINANCE'),
#  ('A', 'MISDEMEANOR', 'D.U.I.'),
#  ('A', 'MISDEMEANOR', 'DISORDERLY CONDUCT'),
#  ('A', 'MISDEMEANOR', 'DISTURBING THE PEACE'),
#  ('A', 'MISDEMEANOR', 'DRUNK: PROT/CUS'),
#  ('A', 'MISDEMEANOR', 'FTA-NON TRAFFIC'),
#  ('A', 'MISDEMEANOR', 'GLUE SNIFFING'),
#  ('A', 'MISDEMEANOR', 'HIT-AND-RUN'),
#  ('A', 'MISDEMEANOR', 'LEWD CONDUCT'),
#  ('A', 'MISDEMEANOR', 'LIQUOR LAWS'),
#  ('A', 'MISDEMEANOR', 'MALICIOUS MISCHIEF'),
#  ('A', 'MISDEMEANOR', 'MANSLAUGHTER-MISD.'),
#  ('A', 'MISDEMEANOR', 'MARIJUANA'),
#  ('A', 'MISDEMEANOR', 'NULL'),
#  ('A', 'MISDEMEANOR', 'OBSCENE MATERIAL'),
#  ('A', 'MISDEMEANOR', 'OTHER DELINQUENCY'),
#  ('A', 'MISDEMEANOR', 'OTHER DRUGS'),
#  ('A', 'MISDEMEANOR', 'OTHER FELONY'),
#  ('A', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('A', 'MISDEMEANOR', 'OTHER THEFT'),
#  ('A', 'MISDEMEANOR', 'PETTY THEFT'),
#  ('A', 'MISDEMEANOR', 'PROSTITUTION'),
#  ('A', 'MISDEMEANOR', 'TRAFFIC-CUST'),
#  ('A', 'MISDEMEANOR', 'TRESPASSING'),
#  ('A', 'MISDEMEANOR', 'TRUANCY'),
#  ('A', 'MISDEMEANOR', 'VANDALISM'),
#  ('A', 'MISDEMEANOR', 'WEAPONS'),
#  ('A', 'OTHER', 'CURFEW'),
#  ('A', 'OTHER', 'DRUNK: PROT/CUS'),
#  ('A', 'OTHER', 'NULL'),
#  ('C', 'FELONY', 'ASSAULT'),
#  ('C', 'FELONY', 'KIDNAPPING'),
#  ('C', 'FELONY', 'OTHER FELONY'),
#  ('C', 'FELONY', 'OTHER SEX'),
#  ('C', 'MISDEMEANOR', 'ANNOY CHILD'),
#  ('C', 'MISDEMEANOR', 'ASSAULT AND BATTERY'),
#  ('C', 'MISDEMEANOR', 'CI/CO ORDINANCE'),
#  ('C', 'MISDEMEANOR', 'CONTRIB/DELIQ OF MINOR'),
#  ('C', 'MISDEMEANOR', 'CURFEW'),
#  ('C', 'MISDEMEANOR', 'INCORRIGIBLE'),
#  ('C', 'MISDEMEANOR', 'NONSUPPORT'),
#  ('C', 'MISDEMEANOR', 'OBSCENE MATERIAL'),
#  ('C', 'MISDEMEANOR', 'OTHER DELINQUENCY'),
#  ('C', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('C', 'MISDEMEANOR', 'RUNAWAY'),
#  ('C', 'MISDEMEANOR', 'TRUANCY'),
#  ('C', 'OTHER', 'CURFEW'),
#  ('C', 'OTHER', 'NULL'),
#  ('D', 'FELONY', 'ASSAULT'),
#  ('D', 'FELONY', 'OTHER FELONY'),
#  ('D', 'FELONY', 'WEAPONS'),
#  ('D', 'INFRACTION', 'OTHER MISDEMEANOR'),
#  ('D', 'MISDEMEANOR', 'ASSAULT AND BATTERY'),
#  ('D', 'MISDEMEANOR', 'CI/CO ORDINANCE'),
#  ('D', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('D', 'MISDEMEANOR', 'WEAPONS'),
#  ('D', 'OTHER', 'NULL'),
#  ('E', 'FELONY', 'THEFT'),
#  ('E', 'MISDEMEANOR', 'OTHER FELONY'),
#  ('E', 'MISDEMEANOR', 'PETTY THEFT'),
#  ('F', 'FELONY', 'FORGED CHECKS'),
#  ('F', 'FELONY', 'THEFT'),
#  ('F', 'INFRACTION', 'OTHER MISDEMEANOR'),
#  ('F', 'MISDEMEANOR', 'CHECKS/CRDS-CDS'),
#  ('F', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('F', 'MISDEMEANOR', 'OTHER THEFT'),
#  ('F', 'MISDEMEANOR', 'PETTY THEFT'),
#  ('G', 'FELONY', 'BOOKMAKING'),
#  ('G', 'MISDEMEANOR', 'GAMBLING'),
#  ('I', 'OTHER', 'NULL'),
#  ('M', 'FELONY', 'OTHER FELONY'),
#  ('M', 'FELONY', 'VANDALISM'),
#  ('M', 'INFRACTION', 'NULL'),
#  ('M', 'MISDEMEANOR', 'CI/CO ORDINANCE'),
#  ('M', 'MISDEMEANOR', 'JOY RIDING'),
#  ('M', 'MISDEMEANOR', 'MALICIOUS MISCHIEF'),
#  ('M', 'MISDEMEANOR', 'NULL'),
#  ('M', 'MISDEMEANOR', 'OTHER FELONY'),
#  ('M', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('M', 'MISDEMEANOR', 'OTHER THEFT'),
#  ('M', 'MISDEMEANOR', 'VANDALISM'),
#  ('N', 'FELONY', 'DANGER DRUGS'),
#  ('N', 'FELONY', 'MARIJUANA'),
#  ('N', 'FELONY', 'NARCOTICS'),
#  ('N', 'FELONY', 'OTHER DRUGS'),
#  ('N', 'FELONY', 'OTHER FELONY'),
#  ('N', 'INFRACTION', 'CI/CO ORDINANCE'),
#  ('N', 'INFRACTION', 'MARIJUANA'),
#  ('N', 'INFRACTION', 'OTHER MISDEMEANOR'),
#  ('N', 'MISDEMEANOR', 'CI/CO ORDINANCE'),
#  ('N', 'MISDEMEANOR', 'GLUE SNIFFING'),
#  ('N', 'MISDEMEANOR', 'MARIJUANA'),
#  ('N', 'MISDEMEANOR', 'OTHER DRUGS'),
#  ('N', 'MISDEMEANOR', 'OTHER FELONY'),
#  ('N', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('N', 'OTHER', 'NARCOTICS'),
#  ('NULL', 'INFRACTION', 'NULL'),
#  ('NULL', 'MISDEMEANOR', 'NULL'),
#  ('NULL', 'NULL', 'NULL'),
#  ('S', 'FELONY', 'LEWD OR LASCIVIOUS'),
#  ('S', 'FELONY', 'OTHER SEX'),
#  ('S', 'INFRACTION', 'NULL'),
#  ('S', 'MISDEMEANOR', 'ANNOY CHILD'),
#  ('S', 'MISDEMEANOR', 'DISORDERLY CONDUCT'),
#  ('S', 'MISDEMEANOR', 'DISTURBING THE PEACE'),
#  ('S', 'MISDEMEANOR', 'INDECENT EXPOSURE'),
#  ('S', 'MISDEMEANOR', 'LEWD CONDUCT'),
#  ('S', 'MISDEMEANOR', 'OBSCENE MATERIAL'),
#  ('S', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('S', 'MISDEMEANOR', 'PROSTITUTION'),
#  ('Y', 'FELONY', 'FORGED CHECKS'),
#  ('Y', 'FELONY', 'OTHER DRUGS'),
#  ('Y', 'FELONY', 'OTHER FELONY'),
#  ('Y', 'FELONY', 'THEFT'),
#  ('Y', 'MISDEMEANOR', 'CHECKS/CRDS-CDS'),
#  ('Y', 'MISDEMEANOR', 'OTHER THEFT'),
#  ('Z', 'FELONY', 'OTHER DRUGS'),
#  ('Z', 'FELONY', 'OTHER FELONY'),
#  ('Z', 'INFRACTION', 'CI/CO ORDINANCE'),
#  ('Z', 'INFRACTION', 'LIQUOR LAWS'),
#  ('Z', 'INFRACTION', 'NULL'),
#  ('Z', 'INFRACTION', 'OTHER MISDEMEANOR'),
#  ('Z', 'INFRACTION', 'WEAPONS'),
#  ('Z', 'MISDEMEANOR', 'ASSAULT AND BATTERY'),
#  ('Z', 'MISDEMEANOR', 'CI/CO ORDINANCE'),
#  ('Z', 'MISDEMEANOR', 'DISTURBING THE PEACE'),
#  ('Z', 'MISDEMEANOR', 'LIQUOR LAWS'),
#  ('Z', 'MISDEMEANOR', 'NULL'),
#  ('Z', 'MISDEMEANOR', 'OTHER MISDEMEANOR'),
#  ('Z', 'MISDEMEANOR', 'TRESPASSING'),
#  ('Z', 'MISDEMEANOR', 'WEAPONS'),
#  ('Z', 'OTHER', 'CI/CO ORDINANCE'),
#  ('Z', 'OTHER', 'NULL')]

# %%
groups = list(dfc[
    [
    'MACRCode',
    'MACRDesc',
    'macrStatus1',
    ]
].groupby([
    'MACRCode',
    'MACRDesc',
    'macrStatus1',
]).groups)
groups
# Out:
# [('ABANDONMENT', '2', 'C'),
#  ('ABANDONMENT', '3', 'C'),
#  ('ABDUCTION FOR DEFILEMENT', '2', 'S'),
#  ('ABORTION - SOLICITING WOMEN', '2', 'C'),
#  ('ACCESSORY', '1', 'A'),
#  ('ACCESSORY', '2', 'A'),
#  ('ACCESSORY', '3', 'A'),
#  ('ACCESSORY', 'NULL', 'A'),
#  ('ADULT INFL MINOR SCHED I-II', '2', 'N'),
#  ('ADULT USE MINOR SCHED III-IV-V', '2', 'N'),
#  ('ADW ON PEACE OFFICER', '2', '4'),
#  ('ADW ON PEACE OFFICER', '3', '4'),
#  ('ADW ON PEACE OFFICER', 'NULL', '4'),
#  ('ADW ON PEACE OFFICER W/FIREARM', '2', '4'),
#  ('ADW ON PEACE OFFICER W/FIREARM', '3', '4'),
#  ('ADW ON PEACE OFFICER W/FIREARM', 'NULL', '4'),
#  ('ALTERING MARKS ON GUN', '2', 'D'),
#  ('ALTERING MARKS ON GUN', '3', 'D'),
#  ('ANNOY CHILD', '2', 'S'),
#  ('ANNOY CHILD', '3', 'S'),
#  ('ANNOY/MOLEST CHILD', '1', 'S'),
#  ('ANNOY/MOLEST CHILD', '2', '2N'),
#  ('ANNOY/MOLEST CHILD', '2', 'C'),
#  ('ANNOY/MOLEST CHILD', '2', 'S'),
#  ('ANNOY/MOLEST CHILD', '3', 'C'),
#  ('ANNOY/MOLEST CHILD', '3', 'S'),
#  ('ANNOY/MOLEST CHILD', 'NULL', 'S'),
#  ('ANNOY/MOLEST CHILD W/PRIOR', '2', 'C'),
#  ('ANNOY/MOLEST CHILD W/PRIOR', '2', 'S'),
#  ('ANNOY/MOLEST CHILD W/PRIOR', '3', 'C'),
#  ('ANNOY/MOLEST CHILD W/PRIOR', 'NULL', 'S'),
#  ('ARSON ATTEMPT', '1', '8'),
#  ('ARSON ATTEMPT', '2', '8'),
#  ('ARSON ATTEMPT', '3', '8'),
#  ('ARSON ATTEMPT', 'NULL', '8'),
#  ('ARSON DEVICE', '2', 'A'),
#  ('ARSON DEVICE', '3', 'A'),
#  ('ARSON DURING EMERGENCY', '2', '8'),
#  ('ARSON INHABITED STRUCTURE', '2', '8'),
#  ('ARSON INHABITED STRUCTURE', '3', '8'),
#  ('ARSON INHABITED STRUCTURE', 'NULL', '8'),
#  ('ARSON PROPERTY', '2', '8'),
#  ('ARSON PROPERTY', '3', '8'),
#  ('ARSON PROPERTY', 'NULL', '8'),
#  ('ARSON STRUCTURE OR FOREST', '2', '8'),
#  ('ARSON STRUCTURE OR FOREST', '3', '8'),
#  ('ARSON STRUCTURE OR FOREST', 'NULL', '8'),
#  ('ASSAULT', '2', '4'),
#  ('ASSAULT BY OFFICER', '3', '4'),
#  ('ASSAULT BY OFFICER', 'NULL', '4'),
#  ('ASSAULT ON SCHOOL OFFICER', '1', '4'),
#  ('ASSAULT ON SCHOOL OFFICER', '2', '4'),
#  ('ASSAULT ON SCHOOL OFFICER', '3', '4'),
#  ('ASSAULT TO COMMIT FELONY', '1', '4'),
#  ('ASSAULT TO COMMIT FELONY', '2', '4'),
#  ('ASSAULT TO COMMIT FELONY', '3', '4'),
#  ('ASSAULT TO COMMIT FELONY', 'NULL', '4'),
#  ('ASSAULT W/DEADLY WEAP/FIREARM', '1', '4'),
#  ('ASSAULT W/DEADLY WEAP/FIREARM', '2', '4'),
#  ('ASSAULT W/DEADLY WEAP/FIREARM', '3', '4'),
#  ('ASSAULT W/DEADLY WEAP/FIREARM', 'NULL', '4'),
#  ('ASSAULT WITH DEADLY WEAPON', '1', '4'),
#  ('ASSAULT WITH DEADLY WEAPON', '2', '4'),
#  ('ASSAULT WITH DEADLY WEAPON', '3', '4'),
#  ('ASSAULT WITH DEADLY WEAPON', 'NULL', '4'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '1', '4'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '1', 'A'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '1', 'D'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '2', '4'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '2', 'A'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '2', 'D'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '3', '4'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '3', 'D'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', '3', 'Z'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', 'NULL', '4'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', 'NULL', 'D'),
#  ('ASSAULT-DISPLAY DEADLY WEAPON', 'NULL', 'Z'),
#  ('ASSULT WITH DANGER SUBSTANCE', '2', '4'),
#  ('ASSULT WITH DANGER SUBSTANCE', '3', '4'),
#  ('ATT CRIME/OFF PERPETRATED', '2', 'A'),
#  ('ATT CRIME/OFF PERPETRATED', '3', 'A'),
#  ('ATT CRIME/OFF PERPETRATED', 'NULL', 'A'),
#  ('ATTEMPTED MURDER', '2', '4'),
#  ('ATTEMPTED MURDER', '3', '4'),
#  ('ATTEMPTED MURDER', 'NULL', '4'),
#  ('BATTERY', '1', '4'),
#  ('BATTERY', '2', '4'),
#  ('BATTERY', '3', '4'),
#  ('BATTERY', 'NULL', '4'),
#  ('BATTERY BY PRISONER', '2', '4'),
#  ('BATTERY BY PRISONER', '3', '4'),
#  ('BATTERY BY PRISONER', 'NULL', '4'),
#  ('BATTERY ON PEACE OFFICER', '1', '4'),
#  ('BATTERY ON PEACE OFFICER', '2', '4'),
#  ('BATTERY ON PEACE OFFICER', '3', '4'),
#  ('BATTERY ON PEACE OFFICER', 'NULL', '4'),
#  ('BOOKMAKING', '2', 'G'),
#  ('BRIBE WITNESS/INFLUENCE JURY', '2', '4'),
#  ('BRIBERY', '2', 'A'),
#  ('BRIBERY', 'NULL', 'A'),
#  ('BUGLARY-ATTEMPT SECOND DEGREE', '2', '5'),
#  ('BURGLARY', '1', '5'),
#  ('BURGLARY', '2', '5'),
#  ('BURGLARY', '3', '5'),
#  ('BURGLARY', 'NULL', '5'),
#  ('BURGLARY-FIRST DEGREE', '2', '5'),
#  ('BURGLARY-FIRST DEGREE', '3', '5'),
#  ('BURGLARY-FIRST DEGREE', 'NULL', '5'),
#  ('BURGLARY-MISD', '1', '5'),
#  ('BURGLARY-MISD', '2', '5'),
#  ('BURGLARY-MISD', '3', '5'),
#  ('BURGLARY-MISD', 'NULL', '5'),
#  ('BURGLARY-SECOND DEGREE', '1', '5'),
#  ('BURGLARY-SECOND DEGREE', '2', '5'),
#  ('BURGLARY-SECOND DEGREE', '3', '5'),
#  ('BURGLARY-SECOND DEGREE', 'NULL', '5'),
#  ('CARJACKING', '1', '3'),
#  ('CARJACKING', '2', '3'),
#  ('CARJACKING', '3', '3'),
#  ('CARJACKING', 'NULL', '3'),
#  ('CARRY CONCEALED WEAPON W/PR', '1', 'D'),
#  ('CARRY CONCEALED WEAPON W/PR', '2', 'D'),
#  ('CARRY CONCEALED WEAPON W/PR', '3', 'D'),
#  ('CARRY CONCEALED WEAPON W/PR', 'NULL', 'D'),
#  ('CARRYING CONCEAL WEAPON ETC', '1', 'D'),
#  ('CARRYING CONCEAL WEAPON ETC', '2', 'D'),
#  ('CARRYING CONCEAL WEAPON ETC', '3', 'A'),
#  ('CARRYING CONCEAL WEAPON ETC', '3', 'D'),
#  ('CARRYING CONCEAL WEAPON ETC', 'NULL', 'A'),
#  ('CARRYING CONCEAL WEAPON ETC', 'NULL', 'D'),
#  ('CHILD BEATING', '1', '4'),
#  ('CHILD BEATING', '1', 'C'),
#  ('CHILD BEATING', '2', '4'),
#  ('CHILD BEATING', '2', 'C'),
#  ('CHILD BEATING', '3', '4'),
#  ('CHILD BEATING', '3', 'C'),
#  ('CHILD BEATING', 'NULL', '4'),
#  ('CHILD BEATING', 'NULL', 'C'),
#  ('CHILD NEGLECT', '1', 'C'),
#  ('CHILD NEGLECT', '2', 'C'),
#  ('CHILD NEGLECT', '3', 'C'),
#  ('CHILD NEGLECT', 'NULL', 'C'),
#  ('CHILD STEALING', '2', 'C'),
#  ('CHILD STEALING', 'NULL', 'C'),
#  ('CITY OR COUNTY ORDINANCE', '1', 'A'),
#  ('CITY OR COUNTY ORDINANCE', '1', 'C'),
#  ('CITY OR COUNTY ORDINANCE', '1', 'D'),
#  ('CITY OR COUNTY ORDINANCE', '1', 'M'),
#  ('CITY OR COUNTY ORDINANCE', '1', 'N'),
#  ('CITY OR COUNTY ORDINANCE', '1', 'Z'),
#  ('CITY OR COUNTY ORDINANCE', '2', 'A'),
#  ('CITY OR COUNTY ORDINANCE', '2', 'D'),
#  ('CITY OR COUNTY ORDINANCE', '2', 'N'),
#  ('CITY OR COUNTY ORDINANCE', '2', 'Z'),
#  ('CITY OR COUNTY ORDINANCE', '3', 'A'),
#  ('CITY OR COUNTY ORDINANCE', '3', 'C'),
#  ('CITY OR COUNTY ORDINANCE', '3', 'D'),
#  ('CITY OR COUNTY ORDINANCE', '3', 'M'),
#  ('CITY OR COUNTY ORDINANCE', '3', 'N'),
#  ('CITY OR COUNTY ORDINANCE', '3', 'Z'),
#  ('CITY OR COUNTY ORDINANCE', 'NULL', 'A'),
#  ('CITY OR COUNTY ORDINANCE', 'NULL', 'C'),
#  ('CITY OR COUNTY ORDINANCE', 'NULL', 'D'),
#  ('CITY OR COUNTY ORDINANCE', 'NULL', 'M'),
#  ('CITY OR COUNTY ORDINANCE', 'NULL', 'N'),
#  ('CITY OR COUNTY ORDINANCE', 'NULL', 'Z'),
#  ('CONSPIRACY TO COMMIT MISD', '1', 'A'),
#  ('CONSPIRACY TO COMMIT MISD', '2', 'A'),
#  ('CONSPIRACY TO COMMIT MISD', '3', 'A'),
#  ('CONSPIRACY TO COMMIT MISD', 'NULL', 'A'),
#  ('CONTEMPT OF COURT', '1', 'A'),
#  ('CONTEMPT OF COURT', '1', 'C'),
#  ('CONTEMPT OF COURT', '1', 'Z'),
#  ('CONTEMPT OF COURT', '2', 'A'),
#  ('CONTEMPT OF COURT', '2', 'C'),
#  ('CONTEMPT OF COURT', '2', 'Z'),
#  ('CONTEMPT OF COURT', '3', 'A'),
#  ('CONTEMPT OF COURT', '3', 'C'),
#  ('CONTEMPT OF COURT', '3', 'Z'),
#  ('CONTEMPT OF COURT', 'NULL', 'A'),
#  ('CONTEMPT OF COURT', 'NULL', 'C'),
#  ('CONTEMPT OF COURT', 'NULL', 'Z'),
#  ('CONTRIB TO DELINQUENCY MINOR', '1', 'C'),
#  ('CONTRIB TO DELINQUENCY MINOR', '2', 'C'),
#  ('CONTRIB TO DELINQUENCY MINOR', '3', 'C'),
#  ('CONTRIB TO DELINQUENCY MINOR', 'NULL', 'C'),
#  ('CREDIT CARD FORGERY', '1', 'F'),
#  ('CREDIT CARD FORGERY', '1', 'Y'),
#  ('CREDIT CARD FORGERY', '2', 'F'),
#  ('CREDIT CARD FORGERY', '2', 'Y'),
#  ('CREDIT CARD FORGERY', '3', 'Y'),
#  ('CREDIT CARD FORGERY', 'NULL', 'F'),
#  ('CREDIT CARD FORGERY', 'NULL', 'Y'),
#  ('CREDIT CARD THEFT', '1', 'F'),
#  ('CREDIT CARD THEFT', '1', 'Y'),
#  ('CREDIT CARD THEFT', '2', 'F'),
#  ('CREDIT CARD THEFT', '2', 'Y'),
#  ('CREDIT CARD THEFT', '3', 'F'),
#  ('CREDIT CARD THEFT', 'NULL', 'F'),
#  ('CREDIT CARD THEFT', 'NULL', 'Y'),
#  ('CREDIT CARD THEFT/USE', '1', 'F'),
#  ('CREDIT CARD THEFT/USE', '2', 'F'),
#  ('CREDIT CARD THEFT/USE', '3', 'F'),
#  ('CREDIT CARD THEFT/USE', 'NULL', 'F'),
#  ('CRIME AGAINST NATURE', '2', '4'),
#  ('CRIMINAL STREET GANG', '1', 'A'),
#  ('CRIMINAL STREET GANG', '2', 'A'),
#  ('CRIMINAL STREET GANG', '3', 'A'),
#  ('CRIMINAL STREET GANG', 'NULL', 'A'),
#  ('CRUEL DEP ADLT W/LKLY GBI/DETH', '1', '4'),
#  ('CRUEL DEP ADLT W/LKLY GBI/DETH', '2', '4'),
#  ('CRUEL DEP ADLT W/LKLY GBI/DETH', '3', '4'),
#  ('CRUEL DEP ADLT W/LKLY GBI/DETH', 'NULL', '4'),
#  ('CRUELTY TO DEPENDANT ADULT', '1', '4'),
#  ('CRUELTY TO DEPENDANT ADULT', '2', '4'),
#  ('CRUELTY TO DEPENDANT ADULT', '3', '4'),
#  ('CRUELTY TO DEPENDANT ADULT', 'NULL', '4'),
#  ('DAMAGE RAIL OR UTILITY LINES', '1', 'M'),
#  ('DAMAGE RAIL OR UTILITY LINES', '2', 'A'),
#  ('DAMAGE RAIL OR UTILITY LINES', '2', 'M'),
#  ('DAMAGE RAIL OR UTILITY LINES', '3', 'M'),
#  ('DELINQUENT - ALL OTHER', '1', 'C'),
#  ('DELINQUENT - ALL OTHER', '2', 'C'),
#  ('DELINQUENT - ALL OTHER', '3', 'C'),
#  ('DELINQUENT - ALL OTHER', 'NULL', 'A'),
#  ('DELINQUENT - ALL OTHER', 'NULL', 'C'),
#  ('DEST DEV POSS W/INT TO INJ', '2', '4'),
#  ('DEST DEV POSS W/INT TO INJ', '2', 'D'),
#  ('DEST DEV POSS W/INT TO INJ', '3', 'D'),
#  ('DEST DEV POSS W/INT TO INJ', 'NULL', '4'),
#  ('DEST DEV POSS W/INT TO INJ', 'NULL', 'D'),
#  ('DEST DEV-MAKE OR PLACE IN VEH', '2', 'D'),
#  ('DISORDERLY CONDUCT', '1', 'A'),
#  ('DISORDERLY CONDUCT', '1', 'S'),
#  ('DISORDERLY CONDUCT', '2', 'A'),
#  ('DISORDERLY CONDUCT', '2', 'S'),
#  ('DISORDERLY CONDUCT', '3', 'A'),
#  ('DISORDERLY CONDUCT', 'NULL', 'A'),
#  ('DISTURBING THE PEACE', '1', 'A'),
#  ('DISTURBING THE PEACE', '2', 'A'),
#  ('DISTURBING THE PEACE', '2', 'S'),
#  ('DISTURBING THE PEACE', '3', 'A'),
#  ('DISTURBING THE PEACE', '3', 'S'),
#  ('DISTURBING THE PEACE', 'NULL', 'A'),
#  ('DISTURBING THE PEACE', 'NULL', 'Z'),
#  ('DIVERSION OF MONEY', '1', 'F'),
#  ('DRUG LAW VIOLATIONS', '2', 'N'),
#  ('DRUG LAW VIOLATIONS', '3', 'N'),
#  ('DRUG LAW VIOLATIONS', 'NULL', 'A'),
#  ('DRUNK', '1', 'A'),
#  ('DRUNK', '2', 'A'),
#  ('DRUNK', '3', 'A'),
#  ('DRUNK', 'NULL', 'A'),
#  ('DRUNK - CIVIL', '2', 'A'),
#  ('DRUNK - CIVIL', '3', 'A'),
#  ('DRUNK - CIVIL', 'NULL', 'A'),
#  ('DRUNK DRIVING', '1', 'A'),
#  ('DRUNK DRIVING', '2', 'A'),
#  ('DRUNK DRIVING', '3', 'A'),
#  ('DRUNK DRIVING', 'NULL', 'A'),
#  ('DRUNK DRIVING  /W INJURY', '2', 'A'),
#  ('DRUNK DRIVING W/INJURY', '1', 'A'),
#  ('DRUNK DRIVING W/INJURY', '2', 'A'),
#  ('DRUNK DRIVING W/INJURY', '3', 'A'),
#  ('DRUNK DRIVING W/INJURY', 'NULL', 'A'),
#  ('EMBEZZLMENT', '1', 'E'),
#  ('EMBEZZLMENT', '2', 'E'),
#  ('EMBEZZLMENT', '3', 'E'),
#  ('EMBEZZLMENT', 'NULL', 'E'),
#  ('ESCAPE  JUVENILE AUTHORITY', '2', 'A'),
#  ('ESCAPE  JUVENILE AUTHORITY', '3', 'A'),
#  ('ESCAPE  JUVENILE AUTHORITY', 'NULL', 'A'),
#  ('ESCAPE FROM JAIL', '2', '4'),
#  ('ESCAPE FROM JAIL', '2', 'A'),
#  ('ESCAPE FROM JAIL', '3', '4'),
#  ('ESCAPE FROM JAIL', '3', 'A'),
#  ('ESCAPE FROM JAIL', 'NULL', '4'),
#  ('ESCAPE FROM JAIL', 'NULL', 'A'),
#  ('ESCAPE FROM PRISON W/FORCE', '2', 'A'),
#  ('ESCAPE FROM PRISON-NO FORCE', '2', 'A'),
#  ('ESCAPE FROM PRISON-NO FORCE', '3', 'A'),
#  ('EVADE P.O. CAUSING INJURY OR D', '1', 'A'),
#  ('EVADE P.O. CAUSING INJURY OR D', '2', '4'),
#  ('EVADE P.O. CAUSING INJURY OR D', '2', 'A'),
#  ('EVADE P.O. CAUSING INJURY OR D', '3', '4'),
#  ('EVADE P.O. CAUSING INJURY OR D', '3', 'A'),
#  ('EVADE P.O. CAUSING INJURY OR D', 'NULL', 'A'),
#  ('EXTORTION', '2', 'A'),
#  ('EXTORTION', '3', 'A'),
#  ('EXTORTION', 'NULL', 'A'),
#  ('EXTORTION - ATTEMPT', '2', 'A'),
#  ('EXTORTION - ATTEMPT', '3', 'A'),
#  ('FAIL TO OBEY JUV CRT', '1', 'C'),
#  ('FAIL TO OBEY JUV CRT', '2', 'C'),
#  ('FAIL TO OBEY JUV CRT', '3', 'C'),
#  ('FAIL TO OBEY JUV CRT', 'NULL', 'C'),
#  ('FAILURE TO APPEAR', '1', 'A'),
#  ('FAILURE TO APPEAR', '2', 'A'),
#  ('FAILURE TO APPEAR', '3', 'A'),
#  ('FAILURE TO APPEAR', 'NULL', 'A'),
#  ('FAILURE TO APPEAR-TRAFFIC', '2', 'A'),
#  ('FAILURE TO APPEAR-TRAFFIC', '3', 'A'),
#  ('FAILURE TO APPEAR-TRAFFIC', 'NULL', 'A'),
#  ('FAILURE TO REGISTER', '1', 'S'),
#  ('FAILURE TO REGISTER', '2', 'S'),
#  ('FAILURE TO REGISTER', '3', 'S'),
#  ('FAILURE TO REGISTER', 'NULL', 'S'),
#  ('FAILURE TO REGISTER WITH PRIOR', '2', 'S'),
#  ('FAILURE TO REGISTER WITH PRIOR', '3', 'S'),
#  ('FAILURE TO REGISTER WITH PRIOR', 'NULL', 'S'),
#  ('FALSE EVID/PREV WIT W/FORCE', '1', 'A'),
#  ('FALSE EVID/PREV WIT W/FORCE', '2', '4'),
#  ('FALSE EVID/PREV WIT W/FORCE', '2', 'A'),
#  ('FALSE EVID/PREV WIT W/FORCE', '3', '4'),
#  ('FALSE EVID/PREV WIT W/FORCE', '3', 'A'),
#  ('FALSE EVID/PREV WIT W/FORCE', 'NULL', 'A'),
#  ('FALSE IMPRISONMENT ETC', '2', 'A'),
#  ('FALSE IMPRISONMENT ETC', '3', 'A'),
#  ('FALSE IMPRISONMENT ETC', 'NULL', 'A'),
#  ('FEDERAL IMMIGRATION', '2', 'Z'),
#  ('FEDERAL IMMIGRATION', '3', 'Z'),
#  ('FEDERAL MILITARY', '3', 'Z'),
#  ('FEDERAL-ALL OTHER', '1', 'A'),
#  ('FEDERAL-ALL OTHER', '2', '3'),
#  ('FEDERAL-ALL OTHER', '2', 'A'),
#  ('FEDERAL-ALL OTHER', '2', 'N'),
#  ('FEDERAL-ALL OTHER', '2', 'Y'),
#  ('FEDERAL-ALL OTHER', '3', 'A'),
#  ('FEDERAL-ALL OTHER', '3', 'Y'),
#  ('FEDERAL-ALL OTHER', 'NULL', 'A'),
#  ('FEDERAL-ALL OTHER', 'NULL', 'N'),
#  ('FELONIES - ALL OTHER', '1', 'A'),
#  ('FELONIES - ALL OTHER', '2', 'A'),
#  ('FELONIES - ALL OTHER', '2', 'C'),
#  ('FELONIES - ALL OTHER', '2', 'D'),
#  ('FELONIES - ALL OTHER', '2', 'M'),
#  ('FELONIES - ALL OTHER', '3', 'A'),
#  ('FELONIES - ALL OTHER', '3', 'D'),
#  ('FELONIES - ALL OTHER', 'NULL', 'A'),
#  ('FELONIES - ALL OTHER', 'NULL', 'D'),
#  ('FELONY - MISCELLANEOUS', '2', '4'),
#  ('FELONY - MISCELLANEOUS', '2', 'A'),
#  ('FELONY ASSAULT', '2', '4'),
#  ('FELONY ASSAULT', '3', '4'),
#  ('FICTITIOUS CHECKS', '1', 'Y'),
#  ('FICTITIOUS CHECKS', '2', 'Y'),
#  ('FICTITIOUS CHECKS', '3', 'Y'),
#  ('FICTITIOUS CHECKS', 'NULL', 'Y'),
#  ('FORCIBLE RAPE', '2', '2'),
#  ('FORCIBLE RAPE', '2', '2N'),
#  ('FORCIBLE RAPE', '3', '2N'),
#  ('FORCIBLE RAPE', 'NULL', '2N'),
#  ('FORGE AUTO REGISTRATION', '1', 'A'),
#  ('FORGE AUTO REGISTRATION', '1', 'Y'),
#  ('FORGE AUTO REGISTRATION', '2', 'Y'),
#  ('FORGE AUTO REGISTRATION', '3', 'Y'),
#  ('FORGE AUTO REGISTRATION', 'NULL', 'Y'),
#  ('FORGERY', '1', 'F'),
#  ('FORGERY', '1', 'Y'),
#  ('FORGERY', '2', 'F'),
#  ('FORGERY', '2', 'Y'),
#  ('FORGERY', '3', 'F'),
#  ('FORGERY', '3', 'Y'),
#  ('FORGERY', 'NULL', 'F'),
#  ('FORGERY', 'NULL', 'Y'),
#  ('FORGERY - ATTEMPTED', '1', 'Y'),
#  ('FORGERY - ATTEMPTED', '2', 'Y'),
#  ('FORGERY - ATTEMPTED', '3', 'Y'),
#  ('FORGERY - ATTEMPTED', 'NULL', 'Y'),
#  ('FRAUD', '1', 'A'),
#  ('FRAUD', '1', 'F'),
#  ('FRAUD', '1', 'M'),
#  ('FRAUD', '1', 'Y'),
#  ('FRAUD', '2', 'A'),
#  ('FRAUD', '2', 'F'),
#  ('FRAUD', '2', 'M'),
#  ('FRAUD', '2', 'Y'),
#  ('FRAUD', '3', 'A'),
#  ('FRAUD', '3', 'F'),
#  ('FRAUD', '3', 'M'),
#  ('FRAUD', '3', 'Y'),
#  ('FRAUD', 'NULL', 'A'),
#  ('FRAUD', 'NULL', 'F'),
#  ('FRAUD', 'NULL', 'M'),
#  ('FRAUD', 'NULL', 'Y'),
#  ('FRAUDLENT CLAIM', '2', 'A'),
#  ('GAMBLING', '1', 'G'),
#  ('GAMBLING', '2', 'G'),
#  ('GAMBLING', '3', 'G'),
#  ('GAMBLING', 'NULL', 'G'),
#  ('GIVE/TRANS-1 OZ OR LESS UNCON', '1', 'A'),
#  ('GIVE/TRANS-1 OZ OR LESS UNCON', '1', 'N'),
#  ('GIVE/TRANS-1 OZ OR LESS UNCON', '2', 'A'),
#  ('GIVE/TRANS-1 OZ OR LESS UNCON', '2', 'N'),
#  ('GIVE/TRANS-1 OZ OR LESS UNCON', '3', 'A'),
#  ('GIVE/TRANS-1 OZ OR LESS UNCON', '3', 'N'),
#  ('GIVE/TRANS-1 OZ OR LESS UNCON', 'NULL', 'A'),
#  ('GLUE SNIFFING', '1', 'A'),
#  ('GLUE SNIFFING', '2', 'A'),
#  ('GLUE SNIFFING', '2', 'N'),
#  ('GLUE SNIFFING', '3', 'A'),
#  ('GLUE SNIFFING', 'NULL', 'A'),
#  ('GRAD THEFT-ANIMAL,FIREARM', '1', '6'),
#  ('GRAD THEFT-ANIMAL,FIREARM', '2', '6'),
#  ('GRAD THEFT-ANIMAL,FIREARM', '3', '6'),
#  ('GRAD THEFT-ANIMAL,FIREARM', 'NULL', '6'),
#  ('GRAND THEFT', '1', '6'),
#  ('GRAND THEFT', '1', 'A'),
#  ('GRAND THEFT', '1', 'F'),
#  ('GRAND THEFT', '2', '6'),
#  ('GRAND THEFT', '2', 'A'),
#  ('GRAND THEFT', '2', 'E'),
#  ('GRAND THEFT', '2', 'F'),
#  ('GRAND THEFT', '3', '6'),
#  ('GRAND THEFT', '3', 'A'),
#  ('GRAND THEFT', '3', 'E'),
#  ('GRAND THEFT', '3', 'F'),
#  ('GRAND THEFT', 'NULL', '6'),
#  ('GRAND THEFT', 'NULL', 'A'),
#  ('GRAND THEFT', 'NULL', 'E'),
#  ('GRAND THEFT', 'NULL', 'F'),
#  ('GRAND THEFT - ATTEMPTED', '2', '6'),
#  ('GRAND THEFT - ATTEMPTED', '3', '6'),
#  ('GRAND THEFT AUTO', '2', '7'),
#  ('GRAND THEFT AUTO', '3', '7'),
#  ('GRAND THEFT AUTO', 'NULL', '7'),
#  ('GRAND THEFT PERSON', '1', '6'),
#  ('GRAND THEFT PERSON', '2', '6'),
#  ('GRAND THEFT PERSON', '3', '6'),
#  ('GRAND THEFT PERSON', 'NULL', '6'),
#  ('GRAND THEFT: IDENTITY THEFT', '1', 'F'),
#  ('GRAND THEFT: IDENTITY THEFT', '2', 'F'),
#  ('GRAND THEFT: IDENTITY THEFT', '3', 'F'),
#  ('GRAND THEFT: IDENTITY THEFT', 'NULL', 'F'),
#  ('HIT AND RUN', '1', 'A'),
#  ('HIT AND RUN', '2', 'A'),
#  ('HIT AND RUN', '3', 'A'),
#  ('HIT AND RUN', 'NULL', 'A'),
#  ('HIT AND RUN W/INJURY', '1', 'A'),
#  ('HIT AND RUN W/INJURY', '2', 'A'),
#  ('HIT AND RUN W/INJURY', '3', 'A'),
#  ('HIT AND RUN W/INJURY', 'NULL', 'A'),
#  ('IGNITION INTERLOCK DEVICE', '1', 'A'),
#  ('IGNITION INTERLOCK DEVICE', '2', 'A'),
#  ('IGNITION INTERLOCK DEVICE', '3', 'A'),
#  ('IGNITION INTERLOCK DEVICE', 'NULL', 'A'),
#  ('INCEST', '2', 'S'),
#  ('INCORRIGIBLE', '3', 'C'),
#  ('INDECENT EXPOSURE', '1', 'S'),
#  ('INDECENT EXPOSURE', '2', 'S'),
#  ('INDECENT EXPOSURE', '3', 'S'),
#  ('INDECENT EXPOSURE', 'NULL', 'S'),
#  ('INDECENT EXPOSURE W/PRIOR', '1', 'S'),
#  ('INDECENT EXPOSURE W/PRIOR', '2', 'S'),
#  ('INDECENT EXPOSURE W/PRIOR', '3', 'S'),
#  ('INDECENT EXPOSURE W/PRIOR', 'NULL', 'S'),
#  ('INJURY TO SPOUSE', '1', '4'),
#  ('INJURY TO SPOUSE', '2', '4'),
#  ('INJURY TO SPOUSE', '3', '4'),
#  ('INJURY TO SPOUSE', 'NULL', '4'),
#  ('INVOLUNTARY MANSLAUGHTER', '2', '1'),
#  ('INVOLUNTARY MANSLAUGHTER', 'NULL', '1'),
#  ('JAIL - CONTRABAND OR DAMAGE', '1', 'A'),
#  ('JAIL - CONTRABAND OR DAMAGE', '1', 'N'),
#  ('JAIL - CONTRABAND OR DAMAGE', '2', 'A'),
#  ('JAIL - CONTRABAND OR DAMAGE', '2', 'N'),
#  ('JAIL - CONTRABAND OR DAMAGE', '3', 'A'),
#  ('JAIL - CONTRABAND OR DAMAGE', '3', 'N'),
#  ('JAIL - CONTRABAND OR DAMAGE', 'NULL', 'A'),
#  ('JAIL - CONTRABAND OR DAMAGE', 'NULL', 'N'),
#  ('KIDNAPPING', '2', 'A'),
#  ('KIDNAPPING', '3', 'A'),
#  ('KIDNAPPING', 'NULL', 'A'),
#  ('KIDNAPPING FOR RANSOM', '2', '3'),
#  ('KIDNAPPING FOR RANSOM', '2', 'A'),
#  ('KIDNAPPING FOR RANSOM', '3', 'A'),
#  ('LEWD CONDUCT', '1', 'A'),
#  ('LEWD CONDUCT', '1', 'S'),
#  ('LEWD CONDUCT', '2', 'A'),
#  ('LEWD CONDUCT', '2', 'S'),
#  ('LEWD CONDUCT', '3', 'A'),
#  ('LEWD CONDUCT', '3', 'S'),
#  ('LEWD CONDUCT', 'NULL', 'A'),
#  ('LEWD CONDUCT', 'NULL', 'S'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', '2', '2N'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', '2', '4'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', '2', 'S'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', '3', '2N'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', '3', '4'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', '3', 'S'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', 'NULL', '2N'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', 'NULL', '4'),
#  ('LEWD/LASCIVIOUS ACTS ON CHILD', 'NULL', 'S'),
#  ('LIQUOR LAW VIOLATION', '1', 'A'),
#  ('LIQUOR LAW VIOLATION', '1', 'Z'),
#  ('LIQUOR LAW VIOLATION', '2', 'A'),
#  ('LIQUOR LAW VIOLATION', '2', 'Z'),
#  ('LIQUOR LAW VIOLATION', '3', 'A'),
#  ('LIQUOR LAW VIOLATION', 'NULL', 'A'),
#  ('LIQUOR LAW VIOLATION', 'NULL', 'Z'),
#  ('LOITERING - CURFEW', '1', 'C'),
#  ('LOITERING - CURFEW', '2', 'C'),
#  ('LOITERING - CURFEW', '3', 'A'),
#  ('LOITERING - CURFEW', '3', 'C'),
#  ('LOITERING - CURFEW', 'NULL', 'C'),
#  ('LYNCHING', '2', 'A'),
#  ('MALICIOUS MISCHIEF', '1', '6'),
#  ('MALICIOUS MISCHIEF', '1', 'A'),
#  ('MALICIOUS MISCHIEF', '1', 'M'),
#  ('MALICIOUS MISCHIEF', '2', '6'),
#  ('MALICIOUS MISCHIEF', '2', 'M'),
#  ('MALICIOUS MISCHIEF', '3', '6'),
#  ('MALICIOUS MISCHIEF', 'NULL', '6'),
#  ('MALICIOUS MISCHIEF', 'NULL', 'M'),
#  ('MANSLAUGHTER - NON-VEHICULAR', '2', '1'),
#  ('MANSLAUGHTER - NON-VEHICULAR', '3', '1'),
#  ('MANSLAUGHTER VEHICLE - NEG', '2', 'A'),
#  ('MANSLAUGHTER VEHICLE - NEG', '3', 'A'),
#  ('MANSLAUGHTER VEHICLE - NON-NEG', '3', 'A'),
#  ('MARIJUANA-ADULT USE MINOR', '2', 'N'),
#  ('MARIJUANA-ADULT USE MINOR', '3', 'N'),
#  ('MARIJUANA-ADULT USE MINOR', 'NULL', 'N'),
#  ('MARIJUANA-POSSESS FOR SALE', '1', 'A'),
#  ('MARIJUANA-POSSESS FOR SALE', '2', 'A'),
#  ('MARIJUANA-POSSESS FOR SALE', '2', 'N'),
#  ('MARIJUANA-POSSESS FOR SALE', '3', 'A'),
#  ('MARIJUANA-POSSESS FOR SALE', '3', 'N'),
#  ('MARIJUANA-POSSESS FOR SALE', 'NULL', 'A'),
#  ('MARIJUANA-POSSESS FOR SALE', 'NULL', 'N'),
#  ('MARIJUANA-POSSESS/PRODUCE', '1', 'N'),
#  ('MARIJUANA-POSSESS/PRODUCE', '2', 'N'),
#  ('MARIJUANA-POSSESS/PRODUCE', '3', 'N'),
#  ('MARIJUANA-POSSESS/PRODUCE', 'NULL', 'N'),
#  ('MARIJUANA-TRANSPORTS/SELLS', '1', 'N'),
#  ('MARIJUANA-TRANSPORTS/SELLS', '2', 'N'),
#  ('MARIJUANA-TRANSPORTS/SELLS', '3', 'N'),
#  ('MARIJUANA-TRANSPORTS/SELLS', 'NULL', 'N'),
#  ('MAYHEM', '1', '4'),
#  ('MAYHEM', '2', '4'),
#  ('MAYHEM', '3', '4'),
#  ('MAYHEM', 'NULL', '4'),
#  ('MFG/DISTRBUTE IMITATION DRUGS', '2', 'N'),
#  ('MFG/DISTRBUTE IMITATION DRUGS', '3', 'N'),
#  ('MFG/SELL/POSS BLOWGUN', '1', 'A'),
#  ('MFG/SELL/POSS BLOWGUN', '1', 'D'),
#  ('MFG/SELL/POSS BLOWGUN', '2', 'D'),
#  ('MFG/SELL/POSS BLOWGUN', '3', 'A'),
#  ('MFG/SELL/POSS BLOWGUN', '3', 'D'),
#  ('MFG/SELL/POSS BLOWGUN', '3', 'Z'),
#  ('MFG/SELL/POSS BLOWGUN', 'NULL', 'A'),
#  ('MFG/SELL/POSS BLOWGUN', 'NULL', 'D'),
#  ('MFG/SELL/POSS BLOWGUN', 'NULL', 'Z'),
#  ('MINOR INFL MINOR SCHED I-II', '2', 'N'),
#  ('MINOR INFL MINOR SCHED I-II', '3', 'N'),
#  ('MISAPPROPRIATION OF PROPERTY', '1', 'E'),
#  ('MISAPPROPRIATION OF PROPERTY', '2', 'E'),
#  ('MISAPPROPRIATION OF PROPERTY', '3', 'E'),
#  ('MISAPPROPRIATION OF PROPERTY', 'NULL', 'E'),
#  ('MISC TRAFFIC', '1', 'A'),
#  ('MISC TRAFFIC', '1', 'F'),
#  ('MISC TRAFFIC', '2', 'A'),
#  ('MISC TRAFFIC', '3', 'A'),
#  ('MISC TRAFFIC', 'NULL', 'A'),
#  ('MISC TRAFFIC', 'NULL', 'Z'),
#  ('MISCELLANEOUS ASSAULT', '1', 'A'),
#  ('MISCELLANEOUS ASSAULT', '2', '4'),
#  ('MISCELLANEOUS ASSAULT', '2', 'A'),
#  ('MISCELLANEOUS ASSAULT', '3', 'A'),
#  ('MISCELLANEOUS ASSAULT', 'NULL', 'A'),
#  ('MISDEMEANOR - ALL OTHER', '1', 'A'),
#  ('MISDEMEANOR - ALL OTHER', '1', 'F'),
#  ('MISDEMEANOR - ALL OTHER', '1', 'M'),
#  ('MISDEMEANOR - ALL OTHER', '1', 'Z'),
#  ('MISDEMEANOR - ALL OTHER', '2', '4'),
#  ('MISDEMEANOR - ALL OTHER', '2', 'A'),
#  ('MISDEMEANOR - ALL OTHER', '2', 'F'),
#  ('MISDEMEANOR - ALL OTHER', '2', 'M'),
#  ('MISDEMEANOR - ALL OTHER', '3', '4'),
#  ('MISDEMEANOR - ALL OTHER', '3', 'A'),
#  ('MISDEMEANOR - ALL OTHER', '3', 'F'),
#  ('MISDEMEANOR - ALL OTHER', '3', 'M'),
#  ('MISDEMEANOR - ALL OTHER', '3', 'Z'),
#  ('MISDEMEANOR - ALL OTHER', 'NULL', '4'),
#  ('MISDEMEANOR - ALL OTHER', 'NULL', 'A'),
#  ('MISDEMEANOR - ALL OTHER', 'NULL', 'D'),
#  ('MISDEMEANOR - ALL OTHER', 'NULL', 'F'),
#  ('MISDEMEANOR - ALL OTHER', 'NULL', 'M'),
#  ('MISDEMEANOR - ALL OTHER', 'NULL', 'Z'),
#  ('MURDER', '2', '1'),
#  ('MURDER', '3', '1'),
#  ('MURDER', 'NULL', '1'),
#  ('MURDER - SECOND DEGREE', '2', '1'),
#  ('MURDER - SECOND DEGREE', '3', '1'),
#  ('MURDER - SECOND DEGREE', 'NULL', '1'),
#  ('MURDER AND NONNEG MANSLAUGHTER', '2', '1'),
#  ('MURDER AND NONNEG MANSLAUGHTER', '2', '4'),
#  ('MURDER AND NONNEG MANSLAUGHTER', 'NULL', '4'),
#  ('NON-SUFFICIENT FUND CHECKS', '1', 'Y'),
#  ('NON-SUFFICIENT FUND CHECKS', '2', 'Y'),
#  ('NON-SUFFICIENT FUND CHECKS', '3', 'Y'),
#  ('NON-SUFFICIENT FUND CHECKS', 'NULL', 'Y'),
#  ('NON-SUPPORT', '1', 'C'),
#  ('NON-SUPPORT', '3', 'C'),
#  ('NULL', '1', ''),
#  ('NULL', '1', 'A'),
#  ('NULL', '1', 'Z'),
#  ('NULL', '2', 'A'),
#  ('NULL', '2', 'Z'),
#  ('NULL', '3', 'A'),
#  ('NULL', '3', 'Z'),
#  ('NULL', 'NULL', ''),
#  ('NULL', 'NULL', '4'),
#  ('NULL', 'NULL', 'A'),
#  ('NULL', 'NULL', 'C'),
#  ('NULL', 'NULL', 'D'),
#  ('NULL', 'NULL', 'I'),
#  ('NULL', 'NULL', 'M'),
#  ('NULL', 'NULL', 'S'),
#  ('NULL', 'NULL', 'Z'),
#  ('OPEN/MAINTAIN PLACE SCHED I-II', '1', 'N'),
#  ('OPEN/MAINTAIN PLACE SCHED I-II', '2', 'N'),
#  ('OPEN/MAINTAIN PLACE SCHED I-II', '3', 'N'),
#  ('OPEN/MAINTAIN PLACE SCHED I-II', 'NULL', 'N'),
#  ('OPERATE VEHICLE W/O CONSENT', '1', '7'),
#  ('OPERATE VEHICLE W/O CONSENT', '2', '7'),
#  ('OPERATE VEHICLE W/O CONSENT', '3', '7'),
#  ('OPERATE VEHICLE W/O CONSENT', 'NULL', '7'),
#  ('OTHER ASSAULT', '1', '4'),
#  ('OTHER ASSAULT', '1', 'A'),
#  ('OTHER ASSAULT', '2', '4'),
#  ('OTHER ASSAULT', '2', 'A'),
#  ('OTHER ASSAULT', '3', '4'),
#  ('OTHER ASSAULT', '3', 'A'),
#  ('OTHER ASSAULT', 'NULL', '4'),
#  ('OTHER ASSAULT', 'NULL', 'A'),
#  ('OTHER DRUGS', '1', 'N'),
#  ('OTHER DRUGS', '2', 'N'),
#  ('OTHER DRUGS', '3', 'N'),
#  ('OTHER DRUGS', 'NULL', 'N'),
#  ('OTHER FELONY SEX', '1', 'S'),
#  ('OTHER FELONY SEX', '2', '2H'),
#  ('OTHER FELONY SEX', '2', '2N'),
#  ('OTHER FELONY SEX', '2', '4'),
#  ('OTHER FELONY SEX', '2', 'A'),
#  ('OTHER FELONY SEX', '2', 'C'),
#  ('OTHER FELONY SEX', '2', 'S'),
#  ('OTHER FELONY SEX', '3', '2H'),
#  ('OTHER FELONY SEX', '3', '2N'),
#  ('OTHER FELONY SEX', '3', '4'),
#  ('OTHER FELONY SEX', '3', 'C'),
#  ('OTHER FELONY SEX', '3', 'S'),
#  ('OTHER FELONY SEX', 'NULL', '2N'),
#  ('OTHER FELONY SEX', 'NULL', 'S'),
#  ('OTHER STATE CODES', '1', 'A'),
#  ('OTHER STATE CODES', '1', 'N'),
#  ('OTHER STATE CODES', '1', 'Z'),
#  ('OTHER STATE CODES', '2', 'A'),
#  ('OTHER STATE CODES', '2', 'Z'),
#  ('OTHER STATE CODES', '3', 'A'),
#  ('OTHER STATE CODES', '3', 'N'),
#  ('OTHER STATE CODES', '3', 'Z'),
#  ('OTHER STATE CODES', 'NULL', 'A'),
#  ('OTHER STATE CODES', 'NULL', 'D'),
#  ('OTHER STATE CODES', 'NULL', 'N'),
#  ('OTHER STATE CODES', 'NULL', 'Z'),
#  ('PANDERING', '2', 'S'),
#  ('PANDERING', '3', 'S'),
#  ('PANDERING', 'NULL', 'S'),
#  ('PARAPHERNALIA', '1', 'A'),
#  ('PARAPHERNALIA', '1', 'N'),
#  ('PARAPHERNALIA', '2', 'A'),
#  ('PARAPHERNALIA', '2', 'N'),
#  ('PARAPHERNALIA', '3', 'A'),
#  ('PARAPHERNALIA', '3', 'N'),
#  ('PARAPHERNALIA', 'NULL', 'A'),
#  ('PARAPHERNALIA', 'NULL', 'N'),
#  ('PAROLE VIOL/FEL', '1', 'A'),
#  ('PAROLE VIOL/FEL', '2', 'A'),
#  ('PAROLE VIOL/FEL', '3', 'A'),
#  ('PAROLE VIOL/FEL', 'NULL', 'A'),
#  ('PAROLE/PROB. VIOL. FEL', '2', 'A'),
#  ('PAROLE/PROB. VIOL. FEL', '2', 'Z'),
#  ('PAROLE/PROB. VIOL. FEL', '3', 'A'),
#  ('PAROLE/PROB. VIOL. FEL', '3', 'Z'),
#  ('PAROLE/PROB. VIOL. FEL', 'NULL', 'Z'),
#  ('PAROLE/PROB. VIOL. MISD', '1', 'A'),
#  ('PAROLE/PROB. VIOL. MISD', '2', 'A'),
#  ('PAROLE/PROB. VIOL. MISD', '2', 'Z'),
#  ('PAROLE/PROB. VIOL. MISD', '3', 'A'),
#  ('PAROLE/PROB. VIOL. MISD', '3', 'Z'),
#  ('PAROLE/PROB. VIOL. MISD', 'NULL', 'A'),
#  ('PAROLE/PROB. VIOL. MISD', 'NULL', 'Z'),
#  ('PERJURY', '2', 'A'),
#  ('PERJURY', '3', 'A'),
#  ('PETTY THEFT', '1', '6'),
#  ('PETTY THEFT', '1', 'A'),
#  ('PETTY THEFT', '1', 'E'),
#  ('PETTY THEFT', '1', 'F'),
#  ('PETTY THEFT', '2', '4'),
#  ('PETTY THEFT', '2', '6'),
#  ('PETTY THEFT', '2', 'A'),
#  ('PETTY THEFT', '2', 'E'),
#  ('PETTY THEFT', '2', 'F'),
#  ('PETTY THEFT', '3', '6'),
#  ('PETTY THEFT', '3', 'A'),
#  ('PETTY THEFT', '3', 'E'),
#  ('PETTY THEFT', '3', 'F'),
#  ('PETTY THEFT', 'NULL', '6'),
#  ('PETTY THEFT', 'NULL', 'A'),
#  ('PETTY THEFT', 'NULL', 'E'),
#  ('PETTY THEFT', 'NULL', 'F'),
#  ('PETTY THEFT WITH PRIOR', '1', '6'),
#  ('PETTY THEFT WITH PRIOR', '2', '6'),
#  ('PETTY THEFT WITH PRIOR', '3', '6'),
#  ('PETTY THEFT WITH PRIOR', 'NULL', '6'),
#  ('PETTY THEFT: IDENTITY THEFT', '1', 'F'),
#  ('PETTY THEFT: IDENTITY THEFT', '2', 'F'),
#  ('PETTY THEFT: IDENTITY THEFT', '3', 'F'),
#  ('PETTY THEFT: IDENTITY THEFT', 'NULL', 'F'),
#  ('PEYOTE-PLANT/CULTIVATE', '1', 'N'),
#  ('PEYOTE-PLANT/CULTIVATE', '2', 'N'),
#  ('PIMPING', '2', 'S'),
#  ('PIMPING', '3', 'S'),
#  ('PLACE NUM OR MARK ON GUN', '1', 'A'),
#  ('PLACE NUM OR MARK ON GUN', '1', 'D'),
#  ('PLACE NUM OR MARK ON GUN', '2', 'A'),
#  ('PLACE NUM OR MARK ON GUN', '2', 'D'),
#  ('PLACE NUM OR MARK ON GUN', '3', 'A'),
#  ('PLACE NUM OR MARK ON GUN', '3', 'D'),
#  ('PLACE NUM OR MARK ON GUN', 'NULL', 'A'),
#  ('PLACE NUM OR MARK ON GUN', 'NULL', 'D'),
#  ('POSS DANGEROUS DRUGS', '1', 'N'),
#  ('POSS DANGEROUS DRUGS', '2', 'N'),
#  ('POSS DANGEROUS DRUGS', '3', 'N'),
#  ('POSS DANGEROUS DRUGS', 'NULL', 'N'),
#  ('POSS DRUGS TO MANUFACTURE DRUG', '1', 'N'),
#  ('POSS DRUGS TO MANUFACTURE DRUG', '2', 'N'),
#  ('POSS DRUGS TO MANUFACTURE DRUG', '2', 'Z'),
#  ('POSS DRUGS TO MANUFACTURE DRUG', '3', 'N'),
#  ('POSS DRUGS TO MANUFACTURE DRUG', '3', 'Z'),
#  ('POSS DRUGS TO MANUFACTURE DRUG', 'NULL', 'N'),
#  ('POSS FOR SALE SCHED I-II', '1', 'N'),
#  ('POSS FOR SALE SCHED I-II', '2', 'N'),
#  ('POSS FOR SALE SCHED I-II', '3', 'N'),
#  ('POSS FOR SALE SCHED I-II', 'NULL', 'N'),
#  ('POSS FOR SALE SCHED III-IV-V', '1', 'N'),
#  ('POSS FOR SALE SCHED III-IV-V', '2', 'N'),
#  ('POSS FOR SALE SCHED III-IV-V', '3', 'N'),
#  ('POSS FOR SALE SCHED III-IV-V', 'NULL', 'N'),
#  ('POSS INSTR TO COMMIT THEFT', '1', 'A'),
#  ('POSS INSTR TO COMMIT THEFT', '2', 'A'),
#  ('POSS INSTR TO COMMIT THEFT', '3', 'A'),
#  ('POSS INSTR TO COMMIT THEFT', 'NULL', 'A'),
#  ('POSS MARIJ - 1 OZ OR LESS UNCN', '1', 'A'),
#  ('POSS MARIJ - 1 OZ OR LESS UNCN', '1', 'N'),
#  ('POSS MARIJ - 1 OZ OR LESS UNCN', '2', 'N'),
#  ('POSS MARIJ - 1 OZ OR LESS UNCN', '3', 'N'),
#  ('POSS MARIJ - 1 OZ OR LESS UNCN', 'NULL', 'A'),
#  ('POSS MARIJ - 1 OZ OR LESS UNCN', 'NULL', 'N'),
#  ('POSS MARIJ - OVER 1 OZ UNCON', '1', 'A'),
#  ('POSS MARIJ - OVER 1 OZ UNCON', '1', 'N'),
#  ('POSS MARIJ - OVER 1 OZ UNCON', '2', 'A'),
#  ('POSS MARIJ - OVER 1 OZ UNCON', '2', 'N'),
#  ('POSS MARIJ - OVER 1 OZ UNCON', '3', 'A'),
#  ('POSS MARIJ - OVER 1 OZ UNCON', '3', 'N'),
#  ('POSS MARIJ - OVER 1 OZ UNCON', 'NULL', 'A'),
#  ('POSS MARIJ - OVER 1 OZ UNCON', 'NULL', 'N'),
#  ('POSS SCHED I-II', '1', 'N'),
#  ('POSS SCHED I-II', '2', 'N'),
#  ('POSS SCHED I-II', '3', 'N'),
#  ('POSS SCHED I-II', 'NULL', 'N'),
#  ('POSS SCHED III-IV-V', '1', 'N'),
#  ('POSS SCHED III-IV-V', '2', 'N'),
#  ('POSS SCHED III-IV-V', '3', 'N'),
#  ('POSS SCHED III-IV-V', 'NULL', 'N'),
#  ('POSS TEAR GAS OR SILENCER', '2', 'D'),
#  ('POSSESS LOADED WEAPON ETC', '1', 'A'),
#  ('POSSESS LOADED WEAPON ETC', '1', 'D'),
#  ('POSSESS LOADED WEAPON ETC', '2', 'A'),
#  ('POSSESS LOADED WEAPON ETC', '2', 'D'),
#  ('POSSESS LOADED WEAPON ETC', '3', 'A'),
#  ('POSSESS LOADED WEAPON ETC', '3', 'D'),
#  ('POSSESS LOADED WEAPON ETC', 'NULL', 'A'),
#  ('POSSESS LOADED WEAPON ETC', 'NULL', 'D'),
#  ('POSSESS WEAPON - CONVICT', '2', 'D'),
#  ('POSSESS WEAPON - CONVICT', '3', 'D'),
#  ('POSSESS WEAPON - EX-CON/ALIEN', '1', 'D'),
#  ('POSSESS WEAPON - EX-CON/ALIEN', '2', 'D'),
#  ('POSSESS WEAPON - EX-CON/ALIEN', '3', 'D'),
#  ('POSSESS WEAPON - EX-CON/ALIEN', 'NULL', 'D'),
#  ('POSSESSING BUGLARY TOOLS', '1', 'A'),
#  ('POSSESSING BUGLARY TOOLS', '2', 'A'),
#  ('POSSESSING BUGLARY TOOLS', '3', 'A'),
#  ('POSSESSING BUGLARY TOOLS', 'NULL', 'A'),
#  ('PRESCRIPTIONS-FORGE/ALTER', '1', 'N'),
#  ('PRESCRIPTIONS-FORGE/ALTER', '1', 'Y'),
#  ('PRESCRIPTIONS-FORGE/ALTER', '2', 'N'),
#  ('PRESCRIPTIONS-FORGE/ALTER', '2', 'Y'),
#  ('PRESCRIPTIONS-FORGE/ALTER', '3', 'N'),
#  ('PRESCRIPTIONS-FORGE/ALTER', '3', 'Y'),
#  ('PRESCRIPTIONS-FORGE/ALTER', 'NULL', 'Y'),
#  ('PROHIBITED WEAPONS', '1', 'A'),
#  ('PROHIBITED WEAPONS', '1', 'D'),
#  ('PROHIBITED WEAPONS', '2', 'A'),
#  ('PROHIBITED WEAPONS', '2', 'D'),
#  ('PROHIBITED WEAPONS', '3', 'A'),
#  ('PROHIBITED WEAPONS', '3', 'D'),
#  ('PROHIBITED WEAPONS', 'NULL', 'D'),
#  ('PROSTITUTION', '1', 'A'),
#  ('PROSTITUTION', '1', 'S'),
#  ('PROSTITUTION', '2', 'A'),
#  ('PROSTITUTION', '2', 'S'),
#  ('PROSTITUTION', '3', 'A'),
#  ('PROSTITUTION', '3', 'S'),
#  ('PROSTITUTION', 'NULL', 'A'),
#  ('PROSTITUTION', 'NULL', 'S'),
#  ('PROSTITUTION-SEDUCTION/ABDUCT', '2', 'S'),
#  ('PROSTITUTION-SEDUCTION/ABDUCT', '3', 'S'),
#  ('PROSTITUTION-SEDUCTION/ABDUCT', 'NULL', 'S'),
#  ('PSYCHOTHER. HAVE SEX W/CLIENT', '1', 'S'),
#  ('PSYCHOTHER. HAVE SEX W/CLIENT', '2', 'S'),
#  ('PSYCHOTHER. HAVE SEX W/CLIENT', '3', '2N'),
#  ('PSYCHOTHER. HAVE SEX W/CLIENT', '3', 'S'),
#  ('PSYCHOTHER. HAVE SEX W/CLIENT', 'NULL', 'S'),
#  ('PUBLIC NUISANCE', '1', 'A'),
#  ('PUBLIC NUISANCE', '2', 'A'),
#  ('PUBLIC NUISANCE', '3', 'A'),
#  ('PUBLIC NUISANCE', 'NULL', 'A'),
#  ('PUBLIC NUISANCE', 'NULL', 'Z'),
#  ('RAPE - ASSAULT TO', '2', '2'),
#  ('RAPE - ASSAULT TO', '3', '2'),
#  ('RAPE - ASSAULT TO', 'NULL', '2'),
#  ('RAPE - ATTEMTED', '2', '2'),
#  ('RAPE - ATTEMTED', '3', '2'),
#  ('RAPE - ATTEMTED', 'NULL', '2'),
#  ('RAPE - SPOUSAL', '2', '2'),
#  ('RAPE - SPOUSAL', '3', '2'),
#  ('RAPE - SPOUSAL', 'NULL', '2'),
#  ('RAPE - VIOLENT', '2', '2'),
#  ('RAPE - VIOLENT', '3', '2'),
#  ('RAPE - VIOLENT', 'NULL', '2'),
#  ('RAPE/CONCERT/FORCE', '2', '2'),
#  ('RECEIVING STOLEN PROPERTY', '1', 'A'),
#  ('RECEIVING STOLEN PROPERTY', '2', 'A'),
#  ('RECEIVING STOLEN PROPERTY', '3', 'A'),
#  ('RECEIVING STOLEN PROPERTY', 'NULL', 'A'),
#  ('RECKLESS DRIVING', '1', 'A'),
#  ('RECKLESS DRIVING', '2', 'A'),
#  ('RECKLESS DRIVING', '3', 'A'),
#  ('RECKLESS DRIVING', 'NULL', 'A'),
#  ('RECKLESS DRIVING W/INJURY', '1', 'A'),
#  ('RESCUE PRISON W/DEATH SENTENCE', '2', 'A'),
#  ('RESISTING A POLICE OFFICER', '1', '4'),
#  ('RESISTING A POLICE OFFICER', '1', 'A'),
#  ('RESISTING A POLICE OFFICER', '2', '4'),
#  ('RESISTING A POLICE OFFICER', '2', 'A'),
#  ('RESISTING A POLICE OFFICER', '3', '4'),
#  ('RESISTING A POLICE OFFICER', '3', 'A'),
#  ('RESISTING A POLICE OFFICER', 'NULL', '4'),
#  ('RESISTING A POLICE OFFICER', 'NULL', 'A'),
#  ('RIOTING', '1', 'A'),
#  ('RIOTING', '2', 'A'),
#  ('RIOTING', '3', 'A'),
#  ('RIOTING', 'NULL', 'A'),
#  ('ROBBERY', '1', '3'),
#  ('ROBBERY', '2', '3'),
#  ('ROBBERY', '3', '3'),
#  ('ROBBERY', 'NULL', '3'),
#  ('ROBBERY - ATTEMPTED', '1', '3'),
#  ('ROBBERY - ATTEMPTED', '2', '3'),
#  ('ROBBERY - ATTEMPTED', '3', '3'),
#  ('ROBBERY - ATTEMPTED', 'NULL', '3'),
#  ('RUNAWAY', '1', 'C'),
#  ('RUNAWAY', '2', 'C'),
#  ('RUNAWAY', '3', 'C'),
#  ('RUNAWAY', 'NULL', 'C'),
#  ('SALE OF OBSCENE MATTER', '1', 'A'),
#  ('SALE OF OBSCENE MATTER', '3', 'A'),
#  ('SALE OF OBSCENE MATTER', '3', 'S'),
#  ('SELECTED TRAFFIC VIOLATIONS', '1', 'A'),
#  ('SELECTED TRAFFIC VIOLATIONS', '2', 'A'),
#  ('SELECTED TRAFFIC VIOLATIONS', '3', 'A'),
#  ('SELL/FURN IN LIEU SCHED I-II', '1', 'N'),
#  ('SELL/FURN IN LIEU SCHED I-II', '2', 'N'),
#  ('SELL/FURN IN LIEU SCHED I-II', '3', 'N'),
#  ('SEX PERV CONFINED PERSON', '2', '2N'),
#  ('SEX PERV CONFINED PERSON', '3', '2N'),
#  ('SEX PERV CONFINED PERSON', 'NULL', '2N'),
#  ('SEX PERV W/CHILD UNDER 14', '2', 'S'),
#  ('SEX PERV W/MINOR UNDER 18', '2', '2N'),
#  ('SEX PERV W/MINOR UNDER 18', '2', 'S'),
#  ('SEX PERV W/MINOR UNDER 18', '3', '2N'),
#  ('SEX PERVERSION', '2', '2N'),
#  ('SEX PERVERSION-ACT IN CONCERT', '2', '2N'),
#  ('SEX PERVERSION-ACT IN CONCERT', '2', 'S'),
#  ('SEX PERVERSION-ACT IN CONCERT', '3', '2N'),
#  ('SEX PERVERSION-ACT IN CONCERT', 'NULL', '2N'),
#  ('SHOOT AT DWELLING/AIRCRAFT', '1', '4'),
#  ('SHOOT AT DWELLING/AIRCRAFT', '2', '4'),
#  ('SHOOT AT DWELLING/AIRCRAFT', '2', 'D'),
#  ('SHOOT AT DWELLING/AIRCRAFT', '3', '4'),
#  ('SHOOT AT DWELLING/AIRCRAFT', '3', 'D'),
#  ('SHOOT AT DWELLING/AIRCRAFT', 'NULL', '4'),
#  ('SIMPLE ASSULT', '1', '4'),
#  ('SIMPLE ASSULT', '2', '4'),
#  ('SIMPLE ASSULT', '3', '4'),
#  ('SIMPLE ASSULT', 'NULL', '4'),
#  ('SODOMY CONFINED PERSON', '2', '2N'),
#  ('SODOMY CONFINED PERSON', '3', '2N'),
#  ('SODOMY W/CHILD UND 14', '2', '2N'),
#  ('SODOMY W/CHILD UND 14', 'NULL', '2N'),
#  ('SODOMY W/MINOR UND 18', '2', '2N'),
#  ('SODOMY W/MINOR UND 18', '3', '2N'),
#  ('SODOMY/CONCERT/FORCE', '2', '2N'),
#  ('SODOMY/CONCERT/FORCE', '3', '2N'),
#  ('TAMPERING WITH VEHICLE', '1', 'A'),
#  ('TAMPERING WITH VEHICLE', '1', 'M'),
#  ('TAMPERING WITH VEHICLE', '2', 'A'),
#  ('TAMPERING WITH VEHICLE', '2', 'M'),
#  ('TAMPERING WITH VEHICLE', '3', 'A'),
#  ('TAMPERING WITH VEHICLE', '3', 'M'),
#  ('TAMPERING WITH VEHICLE', 'NULL', 'A'),
#  ('TAMPERING WITH VEHICLE', 'NULL', 'M'),
#  ('TEMPORARILY TAKING AUTO', '1', '6'),
#  ('TEMPORARILY TAKING AUTO', '1', '7'),
#  ('TEMPORARILY TAKING AUTO', '2', '7'),
#  ('TEMPORARILY TAKING AUTO', '2', 'M'),
#  ('TEMPORARILY TAKING AUTO', '3', '7'),
#  ('TEMPORARILY TAKING AUTO', '3', 'M'),
#  ('THEFT OF AIRCRAFT', '2', '6'),
#  ('THREATEN/ASSAULT AN OFFICER', '1', '4'),
#  ('THREATEN/ASSAULT AN OFFICER', '2', '4'),
#  ('THREATEN/ASSAULT AN OFFICER', '2', 'A'),
#  ('THREATEN/ASSAULT AN OFFICER', '3', '4'),
#  ('THREATEN/ASSAULT AN OFFICER', 'NULL', '4'),
#  ('THROWING AT VEHICLES, ETC', '2', '4'),
#  ('THROWING AT VEHICLES, ETC', '2', 'A'),
#  ('THROWING AT VEHICLES, ETC', '3', '4'),
#  ('THROWING AT VEHICLES, ETC', 'NULL', '4'),
#  ('TRAIN WRECKING', '3', '4'),
#  ('TRANSPORT/SELL SCHED III-IV-V', '1', 'N'),
#  ('TRANSPORT/SELL SCHED III-IV-V', '2', 'N'),
#  ('TRANSPORT/SELL SCHED III-IV-V', '3', 'N'),
#  ('TRANSPORT/SELL SCHED III-IV-V', 'NULL', 'N'),
#  ('TRANSPORTS/SELLS SCHED I-II', '1', 'N'),
#  ('TRANSPORTS/SELLS SCHED I-II', '2', 'N'),
#  ('TRANSPORTS/SELLS SCHED I-II', '3', 'N'),
#  ('TRANSPORTS/SELLS SCHED I-II', 'NULL', 'N'),
#  ('TRESPASSING', '1', 'A'),
#  ('TRESPASSING', '1', 'Z'),
#  ('TRESPASSING', '2', 'A'),
#  ('TRESPASSING', '2', 'Z'),
#  ('TRESPASSING', '3', 'A'),
#  ('TRESPASSING', 'NULL', 'A'),
#  ('TRESPASSING', 'NULL', 'Z'),
#  ('TRUANCY', '1', 'C'),
#  ('TRUANCY', '3', 'A'),
#  ('TRUANCY', '3', 'C'),
#  ('TRUANCY', 'NULL', 'C'),
#  ('UNDER INFLUENCE DANG DRUGS', '2', 'N'),
#  ('UNDER INFLUENCE DANG DRUGS', '3', 'N'),
#  ('UNDER INFLUENCE DANG DRUGS', 'NULL', 'N'),
#  ('UNDER INFLUENCE DRUGS/NARC', '1', 'N'),
#  ('UNDER INFLUENCE DRUGS/NARC', '2', 'N'),
#  ('UNDER INFLUENCE DRUGS/NARC', '3', 'N'),
#  ('UNDER INFLUENCE DRUGS/NARC', 'NULL', 'N'),
#  ('UNLAWFUL FIRE/PROPERTY', '1', '8'),
#  ('UNLAWFUL FIRE/PROPERTY', '2', '8'),
#  ('UNLAWFUL FIRE/PROPERTY', '3', '8'),
#  ('UNLAWFUL FIRE/PROPERTY', 'NULL', '8'),
#  ('UNLAWFUL FIRE/STRUC/FOREST/WBD', '2', '8'),
#  ('UNLAWFUL FIRE/STRUC/FOREST/WBD', '3', '8'),
#  ('UNLAWFUL FIRE/STRUC/FOREST/WBD', 'NULL', '8'),
#  ('UNLAWFUL SEXUAL INTERCOURSE', '2', 'S'),
#  ('UNLAWFUL SEXUAL INTERCOURSE', '3', 'S'),
#  ('UNLAWFUL SEXUAL INTERCOURSE', 'NULL', 'S'),
#  ('USE OF MINOR/OBSC MATTER', '2', 'S'),
#  ('USE OF MINOR/OBSC MATTER', '3', 'C'),
#  ('USE OF MINOR/OBSC MATTER', '3', 'S'),
#  ('VANDALISM/FEL', '1', 'M'),
#  ('VANDALISM/FEL', '2', 'M'),
#  ('VANDALISM/FEL', '3', 'M'),
#  ('VANDALISM/FEL', 'NULL', 'M'),
#  ('VEHICLE CODE 23175 (FELONY)', '1', 'A'),
#  ('VEHICLE CODE 23175 (FELONY)', '2', 'A'),
#  ('VEHICLE CODE 23175 (FELONY)', '2', 'Z'),
#  ('VEHICLE CODE 23175 (FELONY)', '3', 'A'),
#  ('VIO. CIVIL RIGHTS - INJURY', '2', '4'),
#  ('VIO. CIVIL RIGHTS - INJURY', 'NULL', '4'),
#  ('VIO. CIVIL RIGHTS - PROPERTY', '2', 'M'),
#  ('VIOLENT FEL POSSES BODY ARMOR', '1', 'A'),
#  ('VIOLENT FEL POSSES BODY ARMOR', '2', 'A'),
#  ('VIOLENT FEL POSSES BODY ARMOR', '3', 'A'),
#  ('VIOLENT FEL POSSES BODY ARMOR', 'NULL', 'A'),
#  ('VISITING-SCHED I-II', '1', 'N'),
#  ('VISITING-SCHED I-II', '2', 'N'),
#  ('VISITING-SCHED I-II', '3', 'N'),
#  ('VISITING-SCHED I-II', 'NULL', 'N'),
#  ('WARRANT-FELONY', '1', 'Z'),
#  ('WARRANT-FELONY', '2', 'Z'),
#  ...]

# %%
pd.Series([x for x in ''.join([x for x in dfc['highest_codeBcsClass']])]).value_counts()
# Out:
# A    739535
# Z    221238
# N    128071
# F     90814
# 4     64328
# L     45934
# U     22967
# 6     19891
# D     10300
# C      7447
# 5      7360
# M      6639
# 7      6348
# 3      5428
# S      4106
# Y       986
# 8       658
# 2       600
# E       433
# 1       417
# G        41
# I        25
# H         5
# dtype: int64

# %%
max([len(x) for x in dfc.iloc[:, 14]])
# Out:
# 4

# %%
dfc.sample(100).to_csv(local / 'sample_2.csv', index=None)

# %%
dfc['Race'].value_counts(dropna=False)
# Out:
# WHITE               555038
# HISPANIC            409845
# BLACK               160245
# OTHER               104135
# OTHER ASIAN          29916
# HAWAIIAN             28930
# FILIPINO             10329
# INDIAN                4075
# VIETNAMESE            3009
# CHINESE               1906
# PACIFIC ISLANDER      1573
# SAMOAN                1300
# LAOTIAN                826
# KOREAN                 712
# ASIAN INDIAN           632
# JAPANESE               585
# CAMBODIAN              531
# MIDDLE EASTERN         483
# GUAMANIAN              371
# EAST AFRICAN             8
# Name: Race, dtype: int64

# %%
sum(dfc['Race'].isna())
# Out:
# 0

# %%
a = {
    'ASIAN INDIAN',
    'BLACK',
    'CAMBODIAN',
    'CHINESE',
    'EAST AFRICAN',
    'FILIPINO',
    'GUAMANIAN',
    'HAWAIIAN',
    'HISPANIC',
    'INDIAN',
    'JAPANESE',
    'KOREAN',
    'LAOTIAN',
    'MIDDLE EASTERN',
    'OTHER',
    'OTHER ASIAN',
    'PACIFIC ISLANDER',
    'SAMOAN',
    'VIETNAMESE',
    'WHITE',
    'Not Applicable',
    'Missing',
}
b = set(dfc['Race'].unique())

b.difference(a)
# Out:
# set()

# %%
len(dfc.columns)
# Out:
# 42
